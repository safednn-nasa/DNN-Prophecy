# %%
# !git clone --recurse-submodules https://github.com/safednn-nasa/ProphecyPlus
# Out:
# Cloning into 'ProphecyPlus'...
# remote: Enumerating objects: 3112, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 3112 (delta 48), reused 22 (delta 22), pack-reused 3026 (from 3)
# Receiving objects: 100% (3112/3112), 108.24 MiB | 40.79 MiB/s, done.
# Resolving deltas: 100% (1558/1558), done.

# %%
# %cd ./ProphecyPlus
# !pwd
# !ls -lt
# Out:
# /content/ProphecyPlus
# /content/ProphecyPlus
# total 28
# drwxr-xr-x  2 root root 4096 Jan  7 13:56  runtime_detection
# -rw-r--r--  1 root root  124 Jan  7 13:56  requirements.txt
# drwxr-xr-x  2 root root 4096 Jan  7 13:56  examples
# drwxr-xr-x  5 root root 4096 Jan  7 13:56  prophecy
# drwxr-xr-x 10 root root 4096 Jan  7 13:56  dataset_models
# -rw-r--r--  1 root root 2961 Jan  7 13:56  README.md
# drwxr-xr-x  7 root root 4096 Jan  7 13:56 'Legacy Code'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.9/489.9 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.3/229.3 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 11.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# **LOAD MNIST**

# %%
import numpy as np

import tensorflow as tf

import time


import keras


(x_train, y_train), (x_test_orig, y_test_orig) = keras.datasets.mnist.load_data()

len_test = int(0.5 * len(x_test_orig))
print("LEN:", len_test)

x_test = x_test_orig[0:len_test]
x_val = x_test_orig[len_test:]


y_test = y_test_orig[0:len_test]
y_val = y_test_orig[len_test:]

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_val = x_val.reshape(x_val.shape[0], 28, 28, 1)

print(np.shape(x_train))
print(np.shape(x_test))
print(np.shape(x_val))

print(np.shape(y_train))
print(np.shape(y_test))
print(np.shape(y_val))



np.save('./x_train_mnist.npy', x_train)
np.save('./x_test_mnist.npy', x_test)
np.save('./x_val_mnist.npy', x_val)

np.save('./y_train_mnist.npy', y_train)
np.save('./y_test_mnist.npy', y_test)
np.save('./y_val_mnist.npy', y_val)


# !wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/mnist/mnist_cnn.h5 -O ./mnist_cnn.h5


print('Loading the model:')
model_mnist=tf.keras.models.load_model('mnist_cnn.h5')
print("Printing summary of the model:")
model_mnist.summary()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# LEN: 5000
# (60000, 28, 28, 1)
# (5000, 28, 28, 1)
# (5000, 28, 28, 1)
# (60000,)
# (5000,)
# (5000,)
# --2025-01-07 03:22:11--  https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/mnist/mnist_cnn.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 940648 (919K) [application/octet-stream]
# Saving to: ‘./mnist_cnn.h5’
#
# ./mnist_cnn.h5      100%[===================>] 918.60K  --.-KB/s    in 0.06s
#
# 2025-01-07 03:22:11 (15.8 MB/s) - ‘./mnist_cnn.h5’ saved [940648/940648]
#
# Loading the model:
# Printing summary of the model:
# Model: "sequential_1"
# _________________________________________________________________
# ...

# %% [markdown]
# **LOAD CIFAR**

# %%
import numpy as np

import tensorflow as tf

import time


import keras


(x_train, y_train), (x_test_orig, y_test_orig) = keras.datasets.cifar10.load_data()

len_test = int(0.5 * len(x_test_orig))
print("LEN:", len_test)

x_test = x_test_orig[0:len_test]
x_val = x_test_orig[len_test:]


y_test = y_test_orig[0:len_test]
y_val = y_test_orig[len_test:]

x_train = x_train.reshape(x_train.shape[0], 32, 32, 3)
x_test = x_test.reshape(x_test.shape[0], 32, 32, 3)
x_val = x_val.reshape(x_val.shape[0], 32, 32, 3)

print(np.shape(x_train))
print(np.shape(x_test))
print(np.shape(x_val))

print(np.shape(y_train))
print(np.shape(y_test))
print(np.shape(y_val))



np.save('./x_train_cifar.npy', x_train)
np.save('./x_test_cifar.npy', x_test)
np.save('./x_val_cifar.npy', x_val)

np.save('./y_train_cifar.npy', y_train)
np.save('./y_test_cifar.npy', y_test)
np.save('./y_val_cifar.npy', y_val)


# !wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/cifar/model_cifar10_conv.zip -O ./model_cifar10_conv.zip

# !unzip model_cifar10_conv.zip
# !pwd
# !ls -lt

print('Loading the model:')
model_cifar=tf.keras.models.load_model('model_cifar10_conv.h5')
print("Printing summary of the model:")
model_cifar.summary()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step
# LEN: 5000
# (50000, 32, 32, 3)
# (5000, 32, 32, 3)
# (5000, 32, 32, 3)
# (50000, 1)
# (5000, 1)
# (5000, 1)
# --2025-01-07 03:22:29--  https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/cifar/model_cifar10_conv.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18055549 (17M) [application/zip]
# Saving to: ‘./model_cifar10_conv.zip’
#
# ./model_cifar10_con 100%[===================>]  17.22M  --.-KB/s    in 0.1s
#
# 2025-01-07 03:22:29 (148 MB/s) - ‘./model_cifar10_conv.zip’ saved [18055549/18055549]
#
# Archive:  model_cifar10_conv.zip
#   inflating: model_cifar10_conv.h5
# /content/ProphecyPlus
# total 286576
# ...

# %% [markdown]
# **LOAD TABULAR MODELS AND DATASETS.**

# %%
import numpy as np

import tensorflow as tf

import time


import keras


#!wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/non_image/BM1.h5 -O ./BM1.h5

#print('Loading the model:')
#model_BM1=tf.keras.models.load_model('BM1.h5')
#print("Printing summary of the model:")
#model_BM1.summary()

#!wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/non_image/GC1.h5 -O ./GC1.h5

#print('Loading the model:')
#model_GC1=tf.keras.models.load_model('GC1.h5')
#print("Printing summary of the model:")
#model_GC1.summary()

#!wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/non_image/HP1.h5 -O ./HP1.h5

#print('Loading the model:')
#model_HP1=tf.keras.models.load_model('HP1.h5')
#print("Printing summary of the model:")
#model_HP1.summary()

# !wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/non_image/PD1.h5 -O ./PD1.h5

print('Loading the model:')
model_PD1=tf.keras.models.load_model('PD1.h5')
print("Printing summary of the model:")
model_PD1.summary()


# !wget https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/non_image/PD_unseen.csv  -O ./PD.csv

x_csv = np.loadtxt('./PD.csv', delimiter=',',dtype=str)
x_csv = x_csv[1:]
x_csv = x_csv[:, 0:8]
x_csv = x_csv.astype(float)
x_csv_flt = np.zeros((len(x_csv), len(x_csv[0])),dtype=float)
for i in range(len(x_csv)):
  #x_csv[i] = x_csv[i].astype(float)
  for j in range(len(x_csv[i])):
    x_csv_flt[i][j] = float(x_csv[i][j])

x_csv = x_csv_flt

y_csv = np.loadtxt('./PD.csv', delimiter=',',dtype=str)
y_csv = y_csv[1:]
y_csv = y_csv[:, 8]
y_csv = y_csv.astype(int)

print(np.shape(x_csv))
print(x_csv[0])
print(np.shape(y_csv))
print(y_csv[0])


len_ds = int(0.8 * len(x_csv))
print("LEN:", len_ds)

len_test = int(0.2 * 0.5 * len(x_csv))
print("LEN:", len_test)

x_train = x_csv[0:len_ds]
x_test = x_csv[len_ds: len_ds + len_test]
x_val = x_csv[len_ds + len_test:]


y_train = y_csv[0:len_ds]
y_test = y_csv[len_ds:len_ds + len_test]
y_val = y_csv[len_ds + len_test:]



print(np.shape(x_train))
print(np.shape(x_test))
print(np.shape(x_val))

print(np.shape(y_train))
print(np.shape(y_test))
print(np.shape(y_val))



np.save('./x_train_PD.npy', x_train)
np.save('./x_test_PD.npy', x_test)
np.save('./x_val_PD.npy', x_val)

np.save('./y_train_PD.npy', y_train)
np.save('./y_test_PD.npy', y_test)
np.save('./y_val_PD.npy', y_val)
# Out:
# --2025-01-07 14:03:27--  https://raw.githubusercontent.com/safednn-nasa/ProphecyPlus/master/dataset_models/non_image/PD1.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34592 (34K) [application/octet-stream]
# Saving to: ‘./PD1.h5’
#
# ./PD1.h5            100%[===================>]  33.78K  --.-KB/s    in 0.01s
#
# 2025-01-07 14:03:27 (2.96 MB/s) - ‘./PD1.h5’ saved [34592/34592]
#
# Loading the model:
# Printing summary of the model:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **EXTRACT RULES with Neuron Values FOR CORRECT AND INCORRECT BEHAVIOR**

# %%
import os
import shutil
if os.path.exists('/content/drive/MyDrive/prophecy/mnist_rules/'):
  shutil.rmtree('/content/drive/MyDrive/prophecy/mnist_rules/')

os.makedirs('/content/drive/MyDrive/prophecy/mnist_rules/')

# !pwd

# !python -m prophecy.main -m ./'mnist_cnn.h5' -wd '/content/drive/MyDrive/prophecy/mnist_rules/' analyze -tx ./x_train_mnist.npy -ty ./y_train_mnist.npy -vx ./x_test_mnist.npy -vy ./y_test_mnist.npy -odl -oal -type 1
# Out:
# /content/ProphecyPlus
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/ProphecyPlus/prophecy/main.py", line 8, in <module>
#     from prophecy.utils.misc import get_model, read_split
#   File "/content/ProphecyPlus/prophecy/utils/misc.py", line 7, in <module>
#     from tensorflow import keras
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py", line 48, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/__internal__/__init__.py", line 11, in <module>
#     from tensorflow._api.v2.__internal__ import distribute
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__.distribute import combinations
# ...

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/mnist_rules/ruleset.csv"


print("****** RULES ********")
df_op = pd.read_csv(_output_path)
df_op

print("****** MISCLASS RULES ********")
filter_df = df_op[df_op['label'] == 1000]
filter_df
# Out:
# ****** RULES ********
# ****** MISCLASS RULES ********
#              layer  layer_count  \
# 815        dense_1            1
# 816        dense_1            1
# 817        dense_1            1
# 818        dense_1            1
# 819        dense_1            1
# ...            ...          ...
# 6646  activation_4            4
# 6647  activation_4            4
# 6648  activation_4            4
# 6649  activation_4            4
# 6650  activation_4            4
#
#                                                 neurons  \
# 815   [39, 98, 105, 96, 74, 71, 42, 96, 38, 18, 5, 8...
# 816           [39, 98, 66, 12, 121, 45, 3, 110, 69, 17]
# 817   [39, 98, 105, 96, 74, 71, 42, 96, 38, 18, 5, 2...
# 818                   [39, 98, 66, 12, 80, 2, 117, 107]
# 819   [39, 98, 105, 96, 88, 116, 4, 60, 15, 63, 96, ...
# ...                                                 ...
# 6646                              [8, 8, 8, 9, 0, 7, 0]
# 6647                        [8, 8, 8, 9, 0, 7, 0, 7, 7]
# ...

# %% [markdown]
# **Runtime detection of correct classified, incorrectly classified and uncertain inputs**

# %%
import time

start_time = time.time()

# !python -m prophecy.main -m ./'mnist_cnn.h5' -wd '/content/drive/MyDrive/prophecy/mnist_rules/' infer -tx ./x_val_mnist.npy -ty ./y_val_mnist.npy rules

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# DETECT CORRECT, INCORRECT, UNCERTAIN on UNSEEN DATA
# 5000it [13:59,  5.96it/s]
# --- 848.2519228458405 seconds ---

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/mnist_rules/predictions/results.csv"
_stats_path = "/content/drive/MyDrive/prophecy/mnist_rules/predictions/stats.csv"


print("****** RESULTS ********")
df_op = pd.read_csv(_stats_path)
df_op
# Out:
# ****** RESULTS ********
#        idx  corr  inc                                         corr_layer  \
# 0        0     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 1        1     2    2                             ['dense_1', 'dense_2']
# 2        2     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 3        3     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 4        4     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# ...    ...   ...  ...                                                ...
# 4995  4995     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 4996  4996     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 4997  4997     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 4998  4998     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
# 4999  4999     4    0  ['activation_3', 'activation_4', 'dense_1', 'd...
#
#                              inc_layer       eval
# ...

# %% [markdown]
# **Runtime Detection using the classifier tree directly (saves time)**

# %%
import time

start_time = time.time()

# !python -m prophecy.main -m ./'mnist_cnn.h5' -wd '/content/drive/MyDrive/prophecy/mnist_rules/' infer -tx ./x_val_mnist.npy -ty ./y_val_mnist.npy classifiers

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 5000it [00:03, 1498.21it/s]
# --- 11.565759658813477 seconds ---

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/mnist_rules/predictions/results_clf.csv"
_stats_path = "/content/drive/MyDrive/prophecy/mnist_rules/predictions/stats.csv"


print("****** RESULTS ********")
df_op = pd.read_csv(_output_path)
df_op
# Out:
# ****** RESULTS ********
#        idx    outcome
# 0        0    correct
# 1        1  uncertain
# 2        2    correct
# 3        3    correct
# 4        4    correct
# ...    ...        ...
# 4995  4995    correct
# 4996  4996    correct
# 4997  4997    correct
# 4998  4998    correct
# 4999  4999    correct
#
# [5000 rows x 2 columns]

# %% [markdown]
# **EXTRACT AND DETECT FOR CIFAR**

# %%
import os
import shutil
if os.path.exists('/content/drive/MyDrive/prophecy/cifar_rules/'):
  shutil.rmtree('/content/drive/MyDrive/prophecy/cifar_rules/')

os.makedirs('/content/drive/MyDrive/prophecy/cifar_rules/')

# !pwd

# !python -m prophecy.main -m ./'model_cifar10_conv.h5' -wd '/content/drive/MyDrive/prophecy/cifar_rules/' analyze -tx ./x_train_cifar.npy -ty ./y_train_cifar.npy -vx ./x_test_cifar.npy -vy ./y_test_cifar.npy -odl -oal -type 1
# Out:
# /content/ProphecyPlus
# CONFIG PARAMS:
# TYPE: 1 ,INP TYPE: 0 ,ACTS: False ,Top: False
# Dense layers and associated activation layers are considered for fingerprinting
# Layers to be considered for fingerprinting: ['dense_1', 'activation_7', 'dense_2', 'activation_8', 'dense_3', 'activation_9']
# 391/391 [==============================] - 9s 23ms/step
# Evaluating train set: 100% 50000/50000 [00:00<00:00, 467234.05it/s]
# TRAIN: Label 0: 5584, Label 1: 12649, Label 2: 1904, Label 3: 3987, Label 4: 784, Label 5: 4378, Label 6: 2424, Label 7: 6221, Label 8: 5204, Label 9: 6865,
# TRAIN LABELS: (50000,)
# TRAIN ACCURACY: 54.586
# TRAIN LABELS COUNT: {0: 27293, 1000: 22707}
# Invoking Dec-tree classifier based on FEATURES
#
# Fingerprinting TRAIN data after dense_1 layer
# Processing dense_1: 100% 196/196 [00:12<00:00, 15.19it/s]
# Fingerprint after dense_1. ((50000, 1024) inputs, (50000, 1024) neurons)
#
# Fingerprinting TRAIN data after activation_7 layer
# ...

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/cifar_rules/ruleset.csv"


print("****** RULES ********")
df_op = pd.read_csv(_output_path)
df_op

print("****** MISCLASS RULES ********")
filter_df = df_op[df_op['label'] == 1000]
filter_df
# Out:
# ****** RULES ********
# ****** MISCLASS RULES ********
#               layer  layer_count  \
# 2009        dense_1            1
# 2010        dense_1            1
# 2011        dense_1            1
# 2012        dense_1            1
# 2013        dense_1            1
# ...             ...          ...
# 25533  activation_9            6
# 25534  activation_9            6
# 25535  activation_9            6
# 25536  activation_9            6
# 25537  activation_9            6
#
#                                                  neurons  \
# 2009   [294, 629, 967, 615, 911, 109, 450, 433, 882, ...
# 2010   [294, 629, 967, 615, 911, 109, 450, 433, 882, ...
# 2011   [294, 629, 967, 615, 911, 109, 450, 433, 882, ...
# 2012   [294, 629, 967, 615, 911, 109, 450, 433, 376, ...
# 2013   [294, 629, 967, 615, 911, 109, 450, 454, 780, ...
# ...                                                  ...
# 25533                        [1, 9, 1, 8, 1, 1, 0, 6, 3]
# ...

# %%
import time

start_time = time.time()

# !python -m prophecy.main -m ./'model_cifar10_conv.h5' -wd '/content/drive/MyDrive/prophecy/cifar_rules/' infer -tx ./x_val_cifar.npy -ty ./y_val_cifar.npy rules

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# DETECT CORRECT, INCORRECT, UNCERTAIN on UNSEEN DATA
# 5000it [1:01:42,  1.35it/s]
# --- 3714.6018958091736 seconds ---

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/cifar_rules/predictions/results.csv"
_stats_path = "/content/drive/MyDrive/prophecy/cifar_rules/predictions/stats.csv"


print("****** RESULTS ********")
df_op = pd.read_csv(_output_path)
df_op
# Out:
# ****** RESULTS ********
#        idx    outcome
# 0        0    correct
# 1        1    correct
# 2        2    correct
# 3        3  incorrect
# 4        4  incorrect
# ...    ...        ...
# 4995  4995  incorrect
# 4996  4996  incorrect
# 4997  4997    correct
# 4998  4998    correct
# 4999  4999  incorrect
#
# [5000 rows x 2 columns]

# %%
import time

start_time = time.time()

# !python -m prophecy.main -m ./'model_cifar10_conv.h5' -wd '/content/drive/MyDrive/prophecy/cifar_rules/' infer -tx ./x_val_cifar.npy -ty ./y_val_cifar.npy classifiers

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 5000it [00:11, 429.60it/s]
# --- 19.998573303222656 seconds ---

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/cifar_rules/predictions/results_clf.csv"
_stats_path = "/content/drive/MyDrive/prophecy/cifar_rules/predictions/stats.csv"


print("****** RESULTS ********")
df_op = pd.read_csv(_output_path)
df_op
# Out:
# ****** RESULTS ********
#        idx    outcome
# 0        0    correct
# 1        1    correct
# 2        2    correct
# 3        3  incorrect
# 4        4  incorrect
# ...    ...        ...
# 4995  4995  incorrect
# 4996  4996  uncertain
# 4997  4997    correct
# 4998  4998    correct
# 4999  4999  uncertain
#
# [5000 rows x 2 columns]

# %% [markdown]
# **EXTRACT RULES AND DETECT FOR TABULAR DATA.**

# %%
import os
import shutil
if os.path.exists('/content/drive/MyDrive/prophecy/PD_rules/'):
  shutil.rmtree('/content/drive/MyDrive/prophecy/PD_rules/')

os.makedirs('/content/drive/MyDrive/prophecy/PD_rules/')

# !pwd

# !python -m prophecy.main -m ./'PD1.h5' -wd '/content/drive/MyDrive/prophecy/PD_rules/' analyze -tx ./x_train_PD.npy -ty ./y_train_PD.npy -vx ./x_test_PD.npy -vy ./y_test_PD.npy -odl -oal -type 1
# Out:
# /content/ProphecyPlus
# CONFIG PARAMS:
# TYPE: 1 ,INP TYPE: 0 ,ACTS: False ,Top: False
# Dense layers and associated activation layers are considered for fingerprinting
# Layers to be considered for fingerprinting: ['dense', 'dense_1', 'dense_2']
# 1/1 [==============================] - 0s 112ms/step
# Evaluating train set: 100% 122/122 [00:00<00:00, 341364.30it/s]
# TRAIN: Label 0: 79 Label 1: 44
# TRAIN LABELS: (122,)
# TRAIN ACCURACY: 77.8688524590164
# TRAIN LABELS COUNT: {0: 95, 1000: 27}
# Invoking Dec-tree classifier based on FEATURES
#
# Fingerprinting TRAIN data after dense layer
# Fingerprint after dense. ((122, 12) inputs, (122, 12) neurons)
#
# Fingerprinting TRAIN data after dense_1 layer
# Fingerprint after dense_1. ((122, 8) inputs, (122, 8) neurons)
#
# Fingerprinting TRAIN data after dense_2 layer
# Fingerprint after dense_2. ((122, 1) inputs, (122, 1) neurons)
# Inputs: (neuron signature (On/Off activations) dataset)(labels dataset)
# (122, 12) (122,)
# ...

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/PD_rules/ruleset.csv"


print("****** RULES ********")
df_op = pd.read_csv(_output_path)
df_op

print("****** MISCLASS RULES ********")
filter_df = df_op[df_op['label'] == 1000]
filter_df
# Out:
# ****** RULES ********
# ****** MISCLASS RULES ********
#       layer  layer_count                                     neurons  \
# 13    dense            1                         [2, 6, 10, 3, 2, 1]
# 14    dense            1                 [2, 6, 10, 3, 2, 11, 4, 11]
# 15    dense            1                  [2, 6, 10, 3, 2, 1, 4, 10]
# 16    dense            1                                      [2, 2]
# 17    dense            1                 [2, 6, 10, 3, 2, 11, 11, 2]
# 18    dense            1              [2, 6, 10, 3, 2, 11, 4, 11, 8]
# 19    dense            1                            [2, 6, 10, 2, 2]
# 20    dense            1                                   [2, 2, 8]
# 21    dense            1               [2, 6, 10, 3, 2, 1, 4, 11, 1]
# 22    dense            1                     [2, 6, 10, 2, 2, 4, 11]
# 38  dense_1            2                          [1, 6, 7, 1, 1, 4]
# 39  dense_1            2                                [1, 6, 4, 1]
# ...

# %%
import time

start_time = time.time()

# !python -m prophecy.main -m ./'PD1.h5' -wd '/content/drive/MyDrive/prophecy/PD_rules/' infer -tx ./x_val_PD.npy -ty ./y_val_PD.npy rules

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# DETECT CORRECT, INCORRECT, UNCERTAIN on UNSEEN DATA
# 16it [00:00, 132.98it/s]
# --- 8.334877014160156 seconds ---

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/PD_rules/predictions/results.csv"
_stats_path = "/content/drive/MyDrive/prophecy/PD_rules/predictions/stats.csv"


print("****** RESULTS ********")
df_op = pd.read_csv(_output_path)
df_op
# Out:
# ****** RESULTS ********
#     idx    outcome
# 0     0    correct
# 1     1    correct
# 2     2    correct
# 3     3    correct
# 4     4    correct
# 5     5  incorrect
# 6     6    correct
# 7     7    correct
# 8     8  incorrect
# 9     9    correct
# 10   10    correct
# 11   11    correct
# 12   12    correct
# 13   13    correct
# 14   14  incorrect
# 15   15    correct

# %%
import time

start_time = time.time()

# !python -m prophecy.main -m ./'PD1.h5' -wd '/content/drive/MyDrive/prophecy/PD_rules/' infer -tx ./x_val_PD.npy -ty ./y_val_PD.npy classifiers

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 16it [00:00, 248.06it/s]
# --- 8.234351634979248 seconds ---

# %%
import pandas as pd
_output_path = "/content/drive/MyDrive/prophecy/PD_rules/predictions/results_clf.csv"
_stats_path = "/content/drive/MyDrive/prophecy/PD_rules/predictions/stats.csv"


print("****** RESULTS ********")
df_op = pd.read_csv(_output_path)
df_op
# Out:
# ****** RESULTS ********
#     idx    outcome
# 0     0    correct
# 1     1    correct
# 2     2    correct
# 3     3    correct
# 4     4    correct
# 5     5  incorrect
# 6     6    correct
# 7     7    correct
# 8     8  incorrect
# 9     9    correct
# 10   10    correct
# 11   11    correct
# 12   12    correct
# 13   13    correct
# 14   14  incorrect
# 15   15    correct
