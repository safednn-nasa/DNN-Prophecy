# %%
from google.colab import drive
#drive.mount('/content/drive')
#drive.flush_and_unmount()
#!rm -rf /content/drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install tf-keras-vis
# -*- coding: utf-8 -*-
"""GradCam.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1cKjutZfO-CAwKnI4E84NAhm4seqoyGi0
"""

#!pip install tf-keras-vis

import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np
import time
#from Models.loss import smoothL1
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Input, InputLayer
from tensorflow.keras.layers import Activation, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2

from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.gradcam import GradcamPlusPlus

from tf_keras_vis.utils import normalize

import matplotlib.pyplot as plt



import math
import io
import os
from collections import namedtuple
import sys

import operator

import copy

#from tf_keras_vis.utils import num_of_gpus

#_, gpus = num_of_gpus()
#print('{} GPUs'.format(gpus))
# !pwd
os.chdir("./drive/MyDrive/Colab Notebooks")
# !pwd
# !ls

print(tf.__version__)

from platform import python_version

print(python_version())

# %%
import os
import keras
import argparse
import numpy as np
import tensorflow as tf
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
#from keras.layers.normalization import BatchNormalization
from keras.layers import Conv2D, Dense, Input, add, Activation, GlobalAveragePooling2D
from keras.callbacks import LearningRateScheduler
from keras.models import Model, load_model
from keras import optimizers, regularizers
from keras import backend as K
import pickle

def get_prediction(img, tensor = None):

    if tensor == "ALL":
        full_list = []
        for tensor in ['dense_1', 'dense_2', 'dense_3']:
            layer_name = tensor
            layer = model.get_layer(layer_name)
            func = K.function(model.input, [layer.output])
            imag = np.expand_dims(img,axis=0)
            outputs = func(imag)
           # print(outputs)
            layer_outputs_test = []
            fingerprint1 = ((outputs[0] > 0.0).astype('int'))
            layer_outputs_test = []
            layer_result = fingerprint1
            layer_outputs_test.append(layer_result[0])
            full_list.append(layer_outputs_test)

        new_list = [list(full_list[0][0])+list(full_list[1][0])+list(full_list[2][0])]
        layer_outputs_test = np.asarray(new_list)
        return layer_outputs_test
    else:
        layer_name = tensor
        layer = model.get_layer(layer_name)
        func = K.function(model.input, [layer.output])
        imag = np.expand_dims(img,axis=0)
        outputs = func(imag)
       # print(outputs)
        fingerprint1 = ((outputs[0] > 0.0).astype('int'))
        layer_outputs_test = []
        layer_result = fingerprint1
        layer_outputs_test.append(layer_result[0])
        layer_outputs_test = np.asarray(layer_outputs_test)

        return layer_outputs_test

def get_prediction_vals(img, tensor = None):

    if tensor == "ALL":
        full_list = []
        for tensor in ['activation_1','activation_2','activation_3']:
            layer_name = tensor
            layer = model.get_layer(layer_name)
            func = K.function(model.input, [layer.output])
            imag = np.expand_dims(img,axis=0)
            outputs = func(imag)
            op = np.array(outputs)
            #print(op.shape)
            flat_op = op.flatten()
            #print(flat_op.shape)
            fingerprint1 = list(flat_op)
            #print(layer.name,fingerprint1)
            layer_outputs_test = []
            layer_result = fingerprint1
            layer_outputs_test.append(layer_result)
            full_list.append(layer_outputs_test)

        new_list = [list(full_list[0][0])+list(full_list[1][0])+list(full_list[2][0])]
        layer_outputs_test = np.asarray(new_list)
        return layer_outputs_test
    else:
        layer_name = tensor
        layer = model.get_layer(layer_name)
        func = K.function(model.input, [layer.output])
        imag = np.expand_dims(img,axis=0)
        outputs = func(imag)
       # print(outputs)
        #fingerprint1 = ((outputs[0] > 0.0).astype('int'))
        fingerprint1 = outputs[0]
        layer_outputs_test = []
        layer_result = fingerprint1
        layer_outputs_test.append(layer_result[0])
        layer_outputs_test = np.asarray(layer_outputs_test)

        return layer_outputs_test





def fingerprint_suffix(img,ten):
    return (get_prediction(img, tensor=ten)>0.0).astype('int')

def fingerprint_suffix_vals(img,ten):
    return get_prediction_vals(img, tensor=ten)

#from tf_keras_vis.gradcam import Gradcam
#from tf_keras_vis.gradcam import GradcamPlusPlus

def model_modifier_act1_layer(current_model):
    target_layer = current_model.get_layer(name='activation_1') #layer is the name of the intermediate layer
    new_model = tf.keras.Model(inputs=current_model.inputs,
                               outputs=target_layer.output)
    new_model.layers[-1].activation = tf.keras.activations.linear
    return new_model

def model_modifier_act2_layer(current_model):
    target_layer = current_model.get_layer(name='activation_2') #layer is the name of the intermediate layer
    new_model = tf.keras.Model(inputs=current_model.inputs,
                               outputs=target_layer.output)
    new_model.layers[-1].activation = tf.keras.activations.linear
    return new_model

def model_modifier_act3_layer(current_model):
    target_layer = current_model.get_layer(name='activation_3') #layer is the name of the intermediate layer
    new_model = tf.keras.Model(inputs=current_model.inputs,
                               outputs=target_layer.output)
    new_model.layers[-1].activation = tf.keras.activations.linear
    return new_model

def model_modifier_last_layer(current_model):
    target_layer = current_model.get_layer(name='activation_5') #layer is the name of the intermediate layer
    new_model = tf.keras.Model(inputs=current_model.inputs,
                               outputs=target_layer.output)
    new_model.layers[-1].activation = tf.keras.activations.linear
    return new_model

def model_modifier_layer(current_model):
    target_layer = current_model.get_layer(name='dense') #layer is the name of the intermediate layer
    new_model = tf.keras.Model(inputs=current_model.inputs,
                               outputs=target_layer.output)
    new_model.layers[-1].activation = tf.keras.activations.linear
    return new_model

def model_modifier_layer_inps(current_model):
    src_layer = current_model.get_layer(name='activation')
    target_layer = current_model.get_layer(name='dense') #layer is the name of the intermediate layer
    new_model = tf.keras.Model(inputs=src_layer.input,
                               outputs=target_layer.output)
    new_model.layers[-1].activation = tf.keras.activations.linear
    return new_model

def loss_gen_sum(node_list):
    def loss(output):
        print(output.shape)
        op = np.array(output)

        #if (op.ndim > 2):
        op = op.flatten()
        output = np.empty((1,len(op)))
        print(output.shape)
        output[0] = op

        loss_val = sum([output[0][i] for i in node_list])/len(node_list)
        return loss_val
    return loss


def loss_gen_sum1(node_list):
    def loss(output):

        loss_val = sum([output[0][i] for i in node_list])/len(node_list)
        return loss_val
    return loss

def loss_gen_sep(node):
    def loss(output):
        loss_val = output[0][node]
        return loss_val
    return loss

#import matplotlib.pyplot as plt
#from keras.models import load_model
print('Loading the model:')
model=load_model('cifar10b_sunrise.h5')#,custom_objects={'smoothL1':smoothL1})
print("Printing summary of the model:")
model.summary()


layer_name = 'dense'
lay = model.get_layer(layer_name)
print(lay.get_config())

layer_name = 'activation_4'
lay = model.get_layer(layer_name)
print(lay.get_config())

layer_name = 'dense_1'
lay = model.get_layer(layer_name)
print(lay.get_config())

layer_name = 'activation_5'
lay = model.get_layer(layer_name)
print(lay.get_config())
# Out:
# Loading the model:
# Printing summary of the model:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               819712
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 890,410
# Trainable params: 890,410
# Non-trainable params: 0
# _________________________________________________________________
# {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 512, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'activation_4', 'trainable': True, 'dtype': 'float32', 'activation': 'relu'}
# {'name': 'dense_1', 'trainable': True, 'dtype': 'float32', 'units': 10, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'activation_5', 'trainable': True, 'dtype': 'float32', 'activation': 'softmax'}

# %%
def check_pattern(layer_vals,suff,neuron_ids,neuron_sig,VAL = False,ALL = False):
   #layer = 'activation_3'  #layer name, get it from the model summary
   #neuron_ids =  [-1,71,-1,20,-1,1,-1,28,-1,79,-1,29,-1,39,-1,49,-1,42,-1,33,-1,114,-1,117,-1,88,-1,31,-1,36,-1,33,-1,17,-1,117,-1,1,-1,28,-1,97] # neuron ids in the pattern
   #neuron_sig =  ['>',0.435630053,'>',4.067234278,'<=',42.78802872,'<=',20.19964218,'<=',41.11421585,'<=',23.87646389,'<=',15.27161694,'<=',36.27468491,'<=',30.84732342,'<=',40.63782883,'<=',25.80421829,'<=',43.16035843,'<=',38.44324303,'<=',66.91875458,'<=',26.18983078,'<=',16.70914364,'<=',41.36343193,'<=',35.72474098,'<=',35.5690403,'<=',14.66370487,'<=',40.59473419189453]

   if (VAL == False):
      if ((suff[:,neuron_ids][0] == neuron_sig).all(axis=0)):
        return True
      else:
        return False

   found = True;

   oper = -1
   for ind in range(0,len(neuron_ids)):
     if (ind % 2 == 0):
       op = neuron_sig[ind]
       if (op == '<='):
         oper = 0
       else:
         oper = 1
     else:
       v = int(neuron_ids[ind])
       vsig = float(neuron_sig[ind])
       val = layer_vals[v]
       #print(v,vsig,val,oper)
       if (oper == 0):
         if (val > vsig):
           found = False
           break
       else:
         if (val <= vsig):
            found = False
            break
       oper = -1

   return found

# %%
import numpy as np
import csv

num_classes = 10

with open('cifar_test', 'rb') as f1:
    testset = pickle.load(f1, encoding='bytes')

x_test = testset['x_test']
y_test = testset['y_test']

ORIG_X = x_test

print ('Number of samples', len(y_test))
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

print("== DONE! ==\n== COLOR PREPROCESSING... ==")
# color preprocessing
x_test = x_test.astype('float32')
mean = [125.307, 122.95, 113.865]
std = [62.9932, 62.0887, 66.7048]
for i in range(3):
    x_test[:, :, :, i] = (x_test[:, :, :, i] - mean[i]) / std[i]

test_Y = (y_test).argmax(axis=1)
test_X = x_test

#a=[]
#path = 'test_Y.txt'
#inputfile = csv.reader(open(path,'r')) # DEFINES THE INPUT FILE
#for row in inputfile: # TRAVERSES ALL ROWS OF DATA
#    c=[]
#    for i in range(0,len(row)):
#        c.append(int(row[i]))
#    a.append(c)
#test_Y = np.array(a)
print("IDEAL LABELS:", test_Y.shape)

#a=[]
#path = 'test_X.txt'
#inputfile = csv.reader(open(path,'r')) # DEFINES THE INPUT FILE
#for row in inputfile: # TRAVERSES ALL ROWS OF DATA
#    c=[]
#    for i in range(0,len(row)):
#        c.append(int(row[i]))
#    c = np.reshape(c, (32,32,3))
#    a.append(c)
#test_X = np.array(a)
print("CLEAN DATA:", test_X.shape)

with open('sunrise_test_10000', 'rb') as f1:
    testset = pickle.load(f1, encoding='bytes')

x_test = testset['x_test']
y_test = testset['y_test']

POIS_ORIG_X = x_test

print ('Number of samples', len(y_test))
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

print("== DONE! ==\n== COLOR PREPROCESSING... ==")
# color preprocessing
x_test = x_test.astype('float32')
mean = [125.307, 122.95, 113.865]
std = [62.9932, 62.0887, 66.7048]
for i in range(3):
    x_test[:, :, :, i] = (x_test[:, :, :, i] - mean[i]) / std[i]

poisoned_x = x_test
poisoned_Y = (y_test).argmax(axis=1)

#a=[]
#path = 'backdoor_test_X.txt'
#inputfile = csv.reader(open(path,'r')) # DEFINES THE INPUT FILE
#for row in inputfile: # TRAVERSES ALL ROWS OF DATA
#    c=[]
#    for i in range(0,len(row)):
#        c.append(int(row[i]))
#    c = np.reshape(c, (32,32,3))
#    a.append(c)
    #print(c)
    #print(c.shape)
#poisoned_x = np.array(a)
print("POISONED INPUTS:", poisoned_x.shape)
print("POSIONED_Y:", poisoned_Y.shape)

poisoned_labels = (model.predict(poisoned_x)).argmax(axis=1)
print("ACTUAL POISONED LABELS:", poisoned_labels.shape)
PASS = 0
FAIL = 0
for indx in range(0, len(poisoned_labels)):
  #print(poisoned_labels[indx])
  if (poisoned_labels[indx] == test_Y[indx]):
    PASS = PASS + 1
  else:
    FAIL = FAIL + 1
print("PASS:", PASS, ",FAIL:", FAIL, ",POISONED ACCURACY:", (PASS/(PASS+FAIL))*100.0)

test_labels = (model.predict(test_X)).argmax(axis=1)
print("ACTUAL TEST LABELS:", test_labels.shape)
PASS = 0
FAIL = 0
for indx in range(0, len(test_labels)):
  if (test_labels[indx] == test_Y[indx]):
    PASS = PASS + 1
  else:
    FAIL = FAIL + 1
print("PASS:", PASS, ",FAIL:", FAIL, ",TEST ACCURACY:", (PASS/(PASS+FAIL))*100.0)
# Out:
# Number of samples 10000
# == DONE! ==
# == COLOR PREPROCESSING... ==
# IDEAL LABELS: (10000,)
# CLEAN DATA: (10000, 32, 32, 3)
# Number of samples 10000
# == DONE! ==
# == COLOR PREPROCESSING... ==
# POISONED INPUTS: (10000, 32, 32, 3)
# POSIONED_Y: (10000,)
# ACTUAL POISONED LABELS: (10000,)
# PASS: 1012 ,FAIL: 8988 ,POISONED ACCURACY: 10.12
# ACTUAL TEST LABELS: (10000,)
# PASS: 8170 ,FAIL: 1830 ,TEST ACCURACY: 81.69999999999999

# %%
from random import randint

gen_data = []
gen_labels = []
val_data = []
val_labels = []

gen_orig_data = []
val_orig_data = []
gen_pois_orig_data = []
val_pois_orig_data = []

indx_clean = []
len_test = len(test_X)
while (len(indx_clean) < 5000):
  value = randint(0,len_test)
  while (value in indx_clean):
    value = randint(0,len_test)
  indx_clean.append(value)


for indx in range(0,len(test_X)):
  if (indx in indx_clean):
    gen_data.append(test_X[indx])
    gen_labels.append(test_Y[indx])
    gen_orig_data.append(ORIG_X[indx])
    gen_pois_orig_data.append(-1)
  else:
 #   if (len(val_data) < 5000):
    val_data.append(test_X[indx])
    val_labels.append(test_Y[indx])
    val_orig_data.append(ORIG_X[indx])
    val_pois_orig_data.append(-1)


indx_poison = []
len_poison = len(poisoned_x)
while (len(indx_poison) < 5000):
  value = randint(0,len_poison)
  while (value in indx_poison):
    value = randint(0,len_poison)
  indx_poison.append(value)


for indx in range(0,len(poisoned_x)):
  if (indx in indx_poison):
    gen_data.append(poisoned_x[indx])
    gen_labels.append(test_Y[indx])
    gen_orig_data.append(POIS_ORIG_X[indx])
    gen_pois_orig_data.append(ORIG_X[indx])
  else:
 #   if (len(val_data) < 5000):
    val_data.append(poisoned_x[indx])
    val_labels.append(test_Y[indx])
    val_orig_data.append(POIS_ORIG_X[indx])
    val_pois_orig_data.append(ORIG_X[indx])

#for indx in range(0,int(len(poisoned_x)/2)):
#  gen_data.append(poisoned_x[indx])
#  gen_labels.append(test_Y[indx])
#  gen_orig_data.append(POIS_ORIG_X[indx])
#  gen_pois_orig_data.append(test_X[indx])

#for indx in range(int(len(poisoned_x)/2),len(poisoned_x) ):
#  val_data.append(poisoned_x[indx])
#  val_labels.append(test_Y[indx])
#  val_orig_data.append(POIS_ORIG_X[indx])
#  val_pois_orig_data.append(test_X[indx])



gen_data = np.asarray(gen_data)
gen_labels = np.asarray(gen_labels)
print("GENERATION DATASET:", gen_data.shape, gen_labels.shape)
preds = model.predict(gen_data)
actuals_gen = preds.argmax(axis=1)

val_data = np.asarray(val_data)
val_labels = np.asarray(val_labels)
print("VAL DATASET:", val_data.shape, val_labels.shape)
preds = model.predict(val_data)
actuals_val = preds.argmax(axis=1)
# Out:
# GENERATION DATASET: (9999, 32, 32, 3) (9999,)
# VAL DATASET: (10001, 32, 32, 3) (10001,)

# %%
#layer_preds
layer = model.get_layer('dense') # activation, activation_2, activation_3, activation_4, activation_5
func = K.function(model.input, [layer.output])
outputs = func(gen_data)
fingerprint = ((outputs[0] > 0.0).astype('int'))
fingerprint1 = outputs[0]

PASS_LABEL_0 = 0
PASS_LABEL_1 = 0
PASS = 0
FAIL = 0
FAIL_P = 0
val_vec = []
val_vec_labels = []
val_vec_labels1 = []
print("VALS from layer:")
#file1 = open('TWITTER_VALS_DENSE.txt', 'w')
for i in range(0,len(fingerprint1)):
  if (actuals_gen[i] == gen_labels[i]):
    PASS = PASS + 1
    val_vec_labels.append(gen_labels[i])
    val_vec_labels1.append(gen_labels[i])
    val_vec.append(np.asarray((fingerprint1[i]).flatten()))
  else:
    FAIL = FAIL + 1
    if (actuals_val[i] == 0):
        FAIL_P = FAIL_P+ 1
    if (actuals_gen[i] == 0):
      val_vec_labels.append(1000)
    else:
      val_vec_labels.append(0 - actuals_gen[i])
    if (gen_labels[i] == 0):
      val_vec_labels1.append(-1000)
    else:
      val_vec_labels1.append(0 - gen_labels[i])
    val_vec.append(np.asarray((fingerprint1[i]).flatten()))


#PASS = 0
#FAIL = 0
#act_vec = []
#act_vec_labels = []
#act_vec_labels1 = []
#gen_fail_labels = []
#FAIL_LABEL_0 = 0
#FAIL_LABEL_1 = 0
#print("ACTS from layer:")
#file1 = open('TWITTER_ACTS_DENSE.txt', 'w')
#FAIL_P = 0

#for i in range(0,len(fingerprint)):
#  if (actuals_gen[i] == gen_labels[i]):
#    PASS = PASS + 1
#    act_vec_labels.append(gen_labels[i])
#    act_vec.append(np.asarray((fingerprint[i]).flatten()))
#  else:
#    FAIL = FAIL + 1
#    if (actuals_val[i] == 0):
#      FAIL_P = FAIL_P+ 1
#    act_vec.append(np.asarray((fingerprint[i]).flatten()))
#    if (actuals_gen[i] == 0):
#      act_vec_labels.append(-1000)
    #else:
    #  act_vec_labels.append(0 - actuals_gen[i])
    #if (gen_labels[i] == 0):
    #   act_vec_labels.append(-1000)
    #else:
    #   act_vec_labels.append(0 - gen_labels[i])

print("GENERATION SET FAIL:", FAIL, ", FAIL POISONED:", FAIL_P,",ACCURACY:" , (PASS/(PASS+FAIL))*100.0)


PASS = 0
FAIL = 0
PASS_LABEL_0 = 0
PASS_LABEL_1 = 0
FAIL_P = 0
for i in range(0,len(val_data)):
  if (actuals_val[i] == val_labels[i]):
    PASS = PASS + 1
  else:
    FAIL = FAIL + 1
    if (actuals_val[i] == 0):
      FAIL_P = FAIL_P+ 1


print("VALIDATION SET FAIL:", FAIL, ", FAIL POISONED:", FAIL_P,",ACCURACY:" , (PASS/(PASS+FAIL))*100.0)
# Out:
# VALS from layer:
# GENERATION SET FAIL: 5401 , FAIL POISONED: 4552 ,ACCURACY: 45.984598459845984
# VALIDATION SET FAIL: 5417 , FAIL POISONED: 4625 ,ACCURACY: 45.83541645835417

# %%
from sklearn import tree

start_time1 = time.time()

val_vec = np.asarray(val_vec)
val_vec_labels = np.asarray(val_vec_labels)
print(val_vec.shape, val_vec_labels.shape)

val_vec_labels1 = np.asarray(val_vec_labels1)
print(val_vec.shape, val_vec_labels1.shape)

## MISCLASSIFICATION PATTERN WITH ACTUAL LABELS
train_suffixes = val_vec
train_predictions = val_vec_labels
basic_estimator = tree.DecisionTreeClassifier()
basic_estimator.fit(val_vec, val_vec_labels)

## MISCLASSIFICATION PATTERN WITH IDEAL LABELS
train_suffixes1 = val_vec
train_predictions1 = val_vec_labels1
basic_estimator1 = tree.DecisionTreeClassifier()
basic_estimator1.fit(val_vec, val_vec_labels1)

PATTERN_TIME = time.time() - start_time1
# Out:
# (9999, 512) (9999,)
# (9999, 512) (9999,)

# %%
from tqdm import tqdm
import operator
import pandas as pd

def get_decision_path(estimator, inp):
  # Extract the decision path taken by an input as an ordered list of indices
  # of the neurons that were evaluated.
  # See: http://scikit-learn.org/stable/auto_examples/tree/plot_unveil_tree_structure.html
  n_nodes = estimator.tree_.node_count
  feature = estimator.tree_.feature

  # First let's retrieve the decision path of each sample. The decision_path
  # method allows to retrieve the node indicator functions. A non zero element of
  # indicator matrix at the position (i, j) indicates that the sample i goes
  # through the node j.
  X_test = [inp]
  node_indicator = estimator.decision_path(X_test)
  # Similarly, we can also have the leaves ids reached by each sample.
  leaf_id = estimator.apply(X_test)
  # Now, it's possible to get the tests that were used to predict a sample or
  # a group of samples. First, let's make it for the sample.
  node_index = node_indicator.indices[node_indicator.indptr[0]:
                                      node_indicator.indptr[1]]
  neuron_ids = []
  for node_id in node_index:
    if leaf_id[0] == node_id:
        continue
    neuron_ids.append(feature[node_id])
  return neuron_ids

def get_suffix_cluster(neuron_ids, neuron_sig,suffixes=train_suffixes):
  # Get the cluster of inputs that such that all inputs in the cluster
  # have provided on/off signature for the provided neurons.
  #
  # The returned cluster is an array of indices (into mnist.train.images).
  return np.where((suffixes[:, neuron_ids] == neuron_sig).all(axis=1))[0]

def is_consistent_cluster(cluster, predictions):
  # Check if all inputs within the cluster have the same prediction.
  # 'cluster' is an array of input ids.
  pred = predictions[cluster[0]]
  for i in cluster:
    if predictions[i] != pred:
      return False
  return True



def get_invariant_inp(estimator, ref_id, suffixes):
  # Returns an invariant found w.r.t. the provided reference input
  # Args
  #  - inp: reference input, shape <784,>
  # Returns:
  #  - cluster: Indices of training inputs that satisfy the invariant
  #  - neuron_id: A list of neurons such that all inputs that agree with
  #    the reference input on the on/off status of these neurons have the
  #    same prediction as the reference input.
  ref_img = mnist_inp_images[ref_id]
  ref_suffix = suffixes[ref_id]
  print('PREFIX',ref_suffix)
  neuron_ids = get_decision_path(estimator, ref_suffix)
  print('NEURON IDS',neuron_ids)
  neuron_sig = ref_suffix[neuron_ids]
  print('NEURON SIGNATURE',neuron_sig)
  cluster = get_suffix_cluster(neuron_ids, neuron_sig,suffixes)
  imgs = []
  cnt = 0
  for indx1 in range(0,len(cluster)):
    img = mnist.train.images(cluster[indx1])
    fnd = 1
    for i in range(0,len(img)):
      if (ref_img[i] != img[i]):
        fnd = 0
        break
    if (fnd == 1):
        ref_id = cnt
    cnt = cnt + 1
    imgs.append(img)

  imgs_suffixes = fingerprint_signature(imgs,t_fc2)
  ref_suffix = imgs_suffixes[ref_id]
  print('PREFIX',ref_suffix)
  neuron_ids = get_decision_path(estimator, ref_suffix)
  print('NEURON IDS',neuron_ids)
  neuron_sig = ref_suffix[neuron_ids]
  print('NEURON SIGNATURE',neuron_sig)
  cluster = get_suffix_cluster(neuron_ids, neuron_sig,imgs_suffixes)

  return cluster, neuron_ids, neuron_sig

def get_invariant(estimator, ref_id):
  # Returns an invariant found w.r.t. the provided reference input
  # Args
  #  - ref_id: Index (into mnist.train.images) of the reference input
  # Returns:
  #  - cluster: Indices of training inputs that satisfy the invariant
  #  - neuron_id: A list of neurons such that all inputs that agree with
  #    the reference input on the on/off status of these neurons have the
  #    same prediction as the reference input.
  ref_img = mnist.train.images[ref_id]
  ref_suffix = train_suffixes[ref_id]
  neuron_ids = get_decision_path(estimator, ref_suffix)
  neuron_sig = ref_suffix[neuron_ids]
  cluster = get_suffix_cluster(neuron_ids, neuron_sig)
  return cluster, neuron_ids, neuron_sig


def get_all_invariants(estimator):
  # Returns a dictionary mapping each decision tree prediction class
  # to a list of invariants. Each invariant is specified as a triple:
  # - neuron ids
  # - neuron signature (for the neuron ids)
  # - number of training samples that hit it
  # The neuron ids and neuron signature can be supplied to get_suffix_cluster
  # to obtain the cluster of training instances that hit the invariant.
  def is_leaf(node):
    return estimator.tree_.children_left[node] == estimator.tree_.children_right[node]

  def left_child(node):
    return estimator.tree_.children_left[node]

  def right_child(node):
    return estimator.tree_.children_right[node]

  def get_all_paths_rec(node):
    # Returns a list of triples corresponding to paths
    # in the decision tree. Each triple consists of
    # - neurons encountered along the path
    # - signature along the path
    # - prediction class at the leaf
    # - number of training samples that hit the path
    # The prediction class and number of training samples
    # are set to -1 when the leaf is "impure".
    feature = estimator.tree_.feature
    threshold = estimator.tree_.threshold
    if is_leaf(node):
      values = estimator.tree_.value[node][0]
      if len(np.where(values != 0)[0]) == 1:
        cl = estimator.classes_[np.where(values != 0)[0][0]]
        nsamples = estimator.tree_.n_node_samples[node]
      else:
        # impure node
        cl = -1
        nsamples = -1
      return [[[], [], cl, nsamples]]
    # If it is not a leaf both left and right childs must exist
   # paths = [[[feature[node]] + p[0], [0] + p[1], p[2], p[3]] for p in get_all_paths_rec(left_child(node))]
   # paths += [[[feature[node]] + p[0], [1] + p[1], p[2], p[3]] for p in get_all_paths_rec(right_child(node))]
    paths = [[[feature[node]] + p[0],['<='] + [threshold[node]] + p[1], p[2], p[3]] for p in get_all_paths_rec(left_child(node))]
    paths += [[[feature[node]] + p[0],['>'] + [threshold[node]] + p[1], p[2], p[3]] for p in get_all_paths_rec(right_child(node))]
    return paths
  paths =  get_all_paths_rec(0)
  print("Obtained all paths")
  invariants = {}
  for p in tqdm(paths):
    neuron_ids, neuron_sig, cl, nsamples = p
    if cl not in invariants:
      invariants[cl] = []
    # cluster = get_suffix_cluster(neuron_ids, neuron_sig)
    invariants[cl].append([neuron_ids, neuron_sig, nsamples])
  for cl in invariants.keys():
    invariants[cl] = sorted(invariants[cl], key=operator.itemgetter(2), reverse=True)
  return invariants


def describe_cluster(cluster, neuron_ids, show_samples=False):
  neuron_sig = train_suffixes[cluster[0]][neuron_ids]
  print("Num neurons in invariant", len(neuron_ids))
  print("Neuron id and signature")

  for i in range(0,len(neuron_ids)):
    print("id:", neuron_ids[i], "sig:", neuron_sig[i])

  print("Cluster size: ", len(cluster))
  print("Num misclassified", len([i for i in cluster if is_misclassified(i)]))
  if show_samples:
    for i in range(10):
      images = []
      for j in range(10):
        if 10*i + j >= len(cluster):
          break
        images.append(mnist_to_pil_img(mnist.train.images[cluster[10*i+j]]))
      if len(images) > 0:
        show_img(combine(images))

def describe_invariants_all_labels_col(all_invariants,suffixes=train_suffixes,COMMON=False, DEC_PREFX= False):
  invs_sel_neus = []
  invs_sel_sig = []
  Minvs_sel_neus = []
  Minvs_sel_sig = []
  Minvs_sel_supp = []
  invs_sel_supp = []
  invs_sel_cl = []
  Minvs_sel_cl = []

  corr_invs_sel_labs = []
  corr_invs_sel_neus = []
  corr_invs_sel_sig = []
  corr_invs_sel_supp = []

  for cl, invs in all_invariants.items():

    for indx in range (0, len(invs)):
      inv = invs[indx]


     # print("Class:", cl, ", Rule:(neurons:",inv[0],",signature:",inv[1],"),Support:",inv[2])

    # MISCLASSIFICATION PATTTERN FOR IDEAL LABELs
      if (cl < 0):
          Minvs_sel_cl.append(cl)
          Minvs_sel_neus.append(inv[0])
          Minvs_sel_sig.append(inv[1])
          Minvs_sel_supp.append(inv[2])

      # MISCLASSIFICATION PATTTERNs FOR ACTUAL LABELS
      if (cl == 1000):
        invs_sel_neus.append(inv[0])
        invs_sel_sig.append(inv[1])
        invs_sel_supp.append(inv[2])
        invs_sel_cl.append(cl)


      if ((cl >= 0) and (cl not in corr_invs_sel_labs)):
          corr_invs_sel_labs.append(cl)
          corr_invs_sel_neus.append(inv[0])
          corr_invs_sel_sig.append(inv[1])
          corr_invs_sel_supp.append(inv[2])



  return (Minvs_sel_neus, Minvs_sel_sig, Minvs_sel_supp, Minvs_sel_cl, invs_sel_neus, invs_sel_sig, invs_sel_supp, invs_sel_cl, corr_invs_sel_labs, corr_invs_sel_neus, corr_invs_sel_sig, corr_invs_sel_supp)


def describe_invariants_all_labels(all_invariants,suffixes=train_suffixes,COMMON=False, DEC_PREFX= False):
  invs_sel_neus = []
  invs_sel_sig = []
  invs_sel_supp = []
  corr_invs_sel_labs = []
  corr_invs_sel_neus = []
  corr_invs_sel_sig = []
  corr_invs_sel_supp = []

 # print("PRINTING PURE RULES WITH SUPPORT MORE THAN 100 FOR EVERY LABEL:");
  supp = 0
  for cl, invs in all_invariants.items():

    for indx in range (0, len(invs)):
      inv = invs[indx]
      if (inv[2] <= 10):
        continue
      #print("Class:", cl, ", Rule:(neurons:",inv[0],",signature:",inv[1],"),Support:",inv[2])
      print("Class:", cl, "Support:",inv[2])
      if (cl == -1000):
        if (inv[2] > ((10/100) * FAIL_P)):
          invs_sel_neus.append(inv[0])
          invs_sel_sig.append(inv[1])
          invs_sel_supp.append(inv[2])
          supp = supp + inv[2]

      if ((cl >= 0) and (cl not in corr_invs_sel_labs)):
          corr_invs_sel_labs.append(cl)
          corr_invs_sel_neus.append(inv[0])
          corr_invs_sel_sig.append(inv[1])
          corr_invs_sel_supp.append(inv[2])

      continue

      cls = get_suffix_cluster(inv[0],inv[1],suffixes)

      neurons = inv[0]
      signature = inv[1]

      if (len(cls) <= 10):
         continue

     # fail_cnt = []
     # fail_label = []
     # pass_cnt = []
     # for ind in range(0,len(cls)):
     #   inp_indx = cls[ind]
     #   if (FP[inp_indx] == 0):
     #     fail_cnt.append(inp_indx)
     #     fail_label.append(IDEAL[inp_indx])
     #   else:
     #     pass_cnt.append(inp_indx)

      #fail_perc = (fail_cnt/len(cls))
      #if (inv[2] == 243):
      #print("Class:", cl, ", Rule:(neurons:",inv[0],",signature:",inv[1],"),Support:",inv[2],",Pass:",[i for i in pass_cnt],",Mis:",[i for i in fail_cnt] , ",Label:",[i for i in fail_label]);

      print("Class:", cl, ", Rule:(neurons:",inv[0],",signature:",inv[1],"),Support:",inv[2])
      #if (indx > 0):
      #  break
     # for ind in range(0, len(cls)):
     #    print(cls[ind])

     # break
      if (COMMON == True):
          common_nodes(cls,suffixes)

      if (DEC_PREFX == True):
          decision_prefs(cls,suffixes)

  return (invs_sel_neus, invs_sel_sig, invs_sel_supp, corr_invs_sel_labs, corr_invs_sel_neus, corr_invs_sel_sig, corr_invs_sel_supp)


def common_nodes(cls,suffixes):
    cnt = 0
    common = np.zeros(10,dtype=int)
    prev = np.zeros(10,dtype=int)

    for indx in range(0, len(cls)):
        i = cls[indx]
        cnt = cnt + 1
        for j in range(0,len(suffixes[i])):
          if (common[j] == -1):
             continue
          if ((indx != 0) and (suffixes[i][j] != prev[j])):
             common[j] = -1
          else:
             common[j] = suffixes[i][j]
          prev[j] = suffixes[i][j]


    print('COMMON NODES IN CLUSTER for CLASS:',cl,cnt)
    com = []
    for k in range(0,len(common)):
        if (common[k] != -1):
           com.append((k,common[k]))
    print(com)

    return

def decision_prefs(cls,suffixes):
    images = mnist.train.images
    imgsCom = []
    imgs = []
    for indx in range(0, len(cls)):
        print('IMG:')
        print(list(zip(images[cls[indx]])))
        imgs.append(images[cls[indx]])
        imgsCom.append(images[cls[indx]])

    dec_prefixes= fingerprint_signature(imgs,layer)
    prefixes = []
    for indx in range(0,len(dec_prefixes)):
       dec_pref = dec_prefixes[indx]

       match = 0
       for indx1 in range(0, len(prefixes)):
          match = 1
          for i in range(0,len(prefixes[indx1])):
             if (dec_pref[i] != prefixes[indx1][i]):
                match = 0
                break
          if (match == 1):
             break

       if (match == 0):
          prefixes.append(dec_pref)

    print('DECISION PREFIXES IN CLUSTER for CLASS:',cl,cnt)
    for k in range(0,len(prefixes)):
      print(prefixes[k])

    return

# %%
#invariants = get_all_invariants(basic_estimator)
#(Ainvs_sel_neus, Ainvs_sel_sig, Ainvs_sel_supp, Acorr_invs_sel_labs, Acorr_invs_sel_neus, Acorr_invs_sel_sig, Acorr_invs_sel_supp) = describe_invariants_all_labels(invariants)
#print("ACTIVATION PATTERNS:")
#for indx in range(0, len(Ainvs_sel_neus)):
#  print(Ainvs_sel_neus[indx], Ainvs_sel_sig[indx], Ainvs_sel_supp[indx])
#for indx in range(0, len(Acorr_invs_sel_labs)):
#  print(Acorr_invs_sel_labs[indx], Acorr_invs_sel_neus[indx], Acorr_invs_sel_sig[indx], Acorr_invs_sel_supp[indx])


#invariants = get_all_invariants(basic_estimator1)
#(invs_sel_neus, invs_sel_sig, invs_sel_supp, corr_invs_sel_labs, corr_invs_sel_neus, corr_invs_sel_sig, corr_invs_sel_supp) = describe_invariants_all_labels(invariants)


invariants_ACT = get_all_invariants(basic_estimator)
(Minvs_sel_neus1, Minvs_sel_sig1, Minvs_sel_sup1, Minvs_sel_cl1,invs_sel_neus, invs_sel_sig, invs_sel_supp, invs_sel_cl, corr_invs_sel_labs, corr_invs_sel_neus, corr_invs_sel_sig, corr_invs_sel_supp) = describe_invariants_all_labels_col(invariants_ACT)


print("\nACTUAL LABEL based PATTERNS:\n")
for indx in range(0, len(invs_sel_neus)):
  print(invs_sel_cl[indx],invs_sel_neus[indx], invs_sel_sig[indx], invs_sel_supp[indx])

invariants_IDEAL = get_all_invariants(basic_estimator1)
(Minvs_sel_neus, Minvs_sel_sig, Minvs_sel_supp, Minvs_sel_cl, invs_sel_neus1, invs_sel_sig1, invs_sel_supp1, invs_sel_cl1, corr_invs_sel_labs1, corr_invs_sel_neus1, corr_invs_sel_sig1, corr_invs_sel_supp1) = describe_invariants_all_labels_col(invariants_IDEAL)

print("\nIDEAL LABEL based PATTERNS:\n")
for indx in range(0, len(Minvs_sel_neus)):
   print(Minvs_sel_cl[indx], Minvs_sel_neus[indx], Minvs_sel_sig[indx], Minvs_sel_supp[indx])

# %%
# INVOKE FOR EVERY CORRECT LABEL
def corr_match_pattern(layer_vals,suff,neuron_ids,neuron_sig):
   max_match_cnt = -1
   for ix in range(0,len(neuron_ids)):
     match_cnt = 0
     oper = -1
     for ind in range(0,len(neuron_ids[ix])):
       if (ind % 2 == 0):
         op = neuron_sig[ix][ind]
         if (op == '<='):
           oper = 0
         else:
           oper = 1
       else:
         v = neuron_ids[ix][ind]
         vsig = neuron_sig[ix][ind]
         val = layer_vals[v]
         # print(v,vsig,val,oper)
         if (oper == 0):
          if (val <= vsig):
            match_cnt = match_cnt + 1
         else:
          if (val > vsig):
            match_cnt = match_cnt + 1
         oper = -1

     if (match_cnt > max_match_cnt):
       max_match_cnt = match_cnt

   return max_match_cnt

def check_pattern_inter(layer_vals,suff,neuron_ids,neuron_sig,VAL = True,ALL=False):

   if (VAL == False):
      if ((suff[:,neuron_ids][0] == neuron_sig).all(axis=0)):
        return True
      else:
        return False


   found = True;
   oper = -1
   layer_vals = (layer_vals).flatten()

   for ix in range(0,len(neuron_ids)):
     found = True
     for ind in range(0,len(neuron_ids[ix])):
       if (ind % 2 == 0):
         op = neuron_sig[ix][ind]
         if (op == '<='):
           oper = 0
         else:
           oper = 1
       else:
         v = neuron_ids[ix][ind]
         vsig = neuron_sig[ix][ind]
         val = layer_vals[v]
         #print(oper, v, vsig, val)
         if (oper == 0):
          if (val > vsig):
            found = False
          #  print('False')
            break
         else:
          if (val <= vsig):
            found = False
           # print('False')
            break
         oper = -1
     if (found == True):
       break

   if (found == False):
      return -1
   else:
     return ix

# %%
REPAIR = False
VAL = True
ALL = False

# %%
def check_pattern(layer_vals,suff,neuron_ids,neuron_sig,VAL = True,ALL=False):
   #layer = 'activation_3'  #layer name, get it from the model summary
   #neuron_ids =  [-1,71,-1,20,-1,1,-1,28,-1,79,-1,29,-1,39,-1,49,-1,42,-1,33,-1,114,-1,117,-1,88,-1,31,-1,36,-1,33,-1,17,-1,117,-1,1,-1,28,-1,97] # neuron ids in the pattern
   #neuron_sig =  ['>',0.435630053,'>',4.067234278,'<=',42.78802872,'<=',20.19964218,'<=',41.11421585,'<=',23.87646389,'<=',15.27161694,'<=',36.27468491,'<=',30.84732342,'<=',40.63782883,'<=',25.80421829,'<=',43.16035843,'<=',38.44324303,'<=',66.91875458,'<=',26.18983078,'<=',16.70914364,'<=',41.36343193,'<=',35.72474098,'<=',35.5690403,'<=',14.66370487,'<=',40.59473419189453]

   if (VAL == False):
      if ((suff[:,neuron_ids][0] == neuron_sig).all(axis=0)):
        return True
      else:
        return False

   found = True;
   #Integer v = null;
	#			Double vsig = null;
	#			String op = null;
	#			int oper = -1;
   oper = -1
   for ind in range(0,len(neuron_ids)):
     if (ind % 2 == 0):
       op = neuron_sig[ind]
       if (op == '<='):
         oper = 0
       else:
         oper = 1
     else:
       v = neuron_ids[ind]
       vsig = neuron_sig[ind]
       val = layer_vals[v]
      # print(v,vsig,val,oper)
       if (oper == 0):
         if (val > vsig):
           found = False
           break
       else:
         if (val <= vsig):
            found = False
            break
       oper = -1

   return found

# %%
#### GUESSING THE IDEAL LABELS BASED ON PATTERNS
neuron_ids =[]
inc_neuron_ids=[]
neuron_sig = []

for indx in range (0, len(invs_sel_neus)):
       neu_ids = []
       for indx1 in range (0, len(invs_sel_neus[indx])):
          neu_ids.append(-1)
          neu_ids.append(invs_sel_neus[indx][indx1])
       neuron_ids.append(neu_ids)
       inc_neuron_ids.append(invs_sel_neus[indx])

for indx in range (0, len(invs_sel_sig)):
       neuron_sig.append(invs_sel_sig[indx])

Mneuron_ids =[]
Minc_neuron_ids=[]
Mneuron_sig = []
Mneuron_cl = []

for ix in range (0, len(Minvs_sel_supp)-1):
    for iy in range(ix +1, len(Minvs_sel_supp)):
        if (Minvs_sel_supp[iy] > Minvs_sel_supp[ix]):
          temp = Minvs_sel_supp[iy]
          Minvs_sel_supp[iy] = Minvs_sel_supp[ix]
          Minvs_sel_supp[ix] = temp
          temp = Minvs_sel_neus[iy]
          Minvs_sel_neus[iy] = Minvs_sel_neus[ix]
          Minvs_sel_neus[ix] = temp
          temp = Minvs_sel_sig[iy]
          Minvs_sel_sig[iy] = Minvs_sel_sig[ix]
          Minvs_sel_sig[ix] = temp
          temp = Minvs_sel_cl[iy]
          Minvs_sel_cl[iy] = Minvs_sel_cl[ix]
          Minvs_sel_cl[ix] = temp


for indx in range (0, len(Minvs_sel_neus)):
      Mneu_ids = []
      for indx1 in range (0, len(Minvs_sel_neus[indx])):
        Mneu_ids.append(-1)
        Mneu_ids.append(Minvs_sel_neus[indx][indx1])
      Mneuron_ids.append(Mneu_ids)
      Minc_neuron_ids.append(Minvs_sel_neus[indx])


for indx in range (0, len(Minvs_sel_sig)):
        Mneuron_sig.append(Minvs_sel_sig[indx])
        Mneuron_cl.append(Minvs_sel_cl[indx])

print("\n MIS-CLASS PATTERNS FOR IDEAL LABELS\n")
for indx in range (0, len(Minvs_sel_neus)):
  print(Minvs_sel_cl[indx],Minvs_sel_supp[indx],Minvs_sel_neus[indx],Minvs_sel_sig[indx])

import copy
x = copy.deepcopy(val_data)
cnt = 0
correct = 0

labels = actuals_val #actuals_gen
ideals = val_labels #gen_labels


true_positives = 0
true_negatives = 0
false_positives = 0
false_negatives = 0
cnt_not_fnd = 0
broke = 0


PASS = 0
PASS_bef = 0
FAIL = 0
FAIL_bef = 0

start_time = time.time()
for inp_cnt in range(0,len(x)): # x is the list of images in the dataset used to extract the mis-classification pattern

    image = x[inp_cnt]
    label = labels[inp_cnt]

    inp = image
    inc_layer = 'dense'  #layer name, get it from the model summary
    inc_suff = fingerprint_suffix_vals(inp, inc_layer)



    layer_vals = inc_suff[0]
    suff = []

    image_array = np.zeros((1,32,32,3),dtype=float)
    image_array[0]=image

    img = np.zeros((32,32,3),dtype=float)
    for ix in range(0,32):
      for iy in range(0,32):
        for iz in range(0,3):
          img[ix][iy][iz] = (float(image[ix][iy][iz]))

    img_mod = np.expand_dims(img,axis=0)


    match = check_pattern_inter(layer_vals,suff,neuron_ids,neuron_sig,VAL,False)

    if (match >= 0):

        print("IDENTIFIED POISONED INPUT", inp_cnt,",", cnt, ",ACT:", labels[inp_cnt], ",IDEAL:", ideals[inp_cnt])
        cnt = cnt + 1

        if (labels[inp_cnt] != 0):
          false_positives = false_positives + 1
        else:
          true_positives = true_positives + 1

        match1 = check_pattern_inter(layer_vals,suff,Mneuron_ids,Mneuron_sig,VAL,ALL)

        if (match1 == -1):
          cnt_not_fnd = cnt_not_fnd + 1
          new_lbl = randint(1,9)
        else:
          new_lbl = -Mneuron_cl[match1]

        print("MATCH1,NEW LABEL:", match1,new_lbl)

        if (new_lbl == ideals[inp_cnt]): #and (labels[inp_cnt] != ideals[inp_cnt]) ):
           correct = correct + 1
           PASS = PASS + 1
        else:
           FAIL = FAIL + 1
           if (labels[inp_cnt] == ideals[inp_cnt]):
             broke = broke + 1

        if (labels[inp_cnt] == ideals[inp_cnt]):
          PASS_bef = PASS_bef + 1
        else:
          FAIL_bef = FAIL_bef + 1


    else:

      if (labels[inp_cnt] != 0):
          true_negatives = true_negatives + 1
      else:
          false_negatives = false_negatives + 1

      if (labels[inp_cnt] == ideals[inp_cnt]):
        PASS_bef = PASS_bef + 1
        PASS = PASS + 1
      else:
        FAIL_bef = FAIL_bef + 1
        FAIL = FAIL + 1

print("\n DISTILLATION BASED ON PATTERNS FOR IDEAL LABEL:")
print('TOTAL IDENTIFIED AS POISONED :',cnt)


print('TP:', true_positives, ',FP:', false_positives, ",TN:", true_negatives, ",FN:", false_negatives)
PREC = ((true_positives)/ (true_positives + false_positives))
RECALL = ((true_positives)/ (true_positives + false_negatives))
print("PRECISION:" , PREC * 100.0, ",RECALL:", RECALL * 100.0)

print('TOTAL GUESSED BASED ON PATTERNs :',(cnt - cnt_not_fnd))
print('CORRECT:', correct)
print('BROKE PREVIOUSLY CORRECTLY CLASSIFIED:', broke)

rep_rate = ((correct/true_positives) * 100.0)
print("REPAIR RATE:", rep_rate)
rep_rate = ((correct/(true_positives + false_negatives)) * 100.0)
print("FULL REPAIR RATE:", rep_rate)


#print("RUNTIME TIME CONSUMED:" , time.time() - start_time)
print("OVERALL ACCURACY without monitor:", (PASS_bef/(PASS_bef+FAIL_bef)) * 100 )
print("OVERALL ACCURACY with monitor:", (PASS/(PASS+FAIL)) * 100 )

print("OFFLINE TIME CONSUMED:" ,PATTERN_TIME)
print("RUNTIME TIME CONSUMED:" , time.time() - start_time)
# Out:
# Streaming output truncated to the last 5000 lines.
# IDENTIFIED POISONED INPUT 7149 , 2022 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1301 4
# IDENTIFIED POISONED INPUT 7151 , 2023 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 550 2
# IDENTIFIED POISONED INPUT 7152 , 2024 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 528 7
# IDENTIFIED POISONED INPUT 7153 , 2025 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 510 2
# IDENTIFIED POISONED INPUT 7154 , 2026 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 372 7
# IDENTIFIED POISONED INPUT 7155 , 2027 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 133 4
# IDENTIFIED POISONED INPUT 7156 , 2028 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1287 4
# IDENTIFIED POISONED INPUT 7157 , 2029 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 7158 , 2030 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 110 3
# IDENTIFIED POISONED INPUT 7159 , 2031 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 38 5
# IDENTIFIED POISONED INPUT 7160 , 2032 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 7161 , 2033 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 6 1
# IDENTIFIED POISONED INPUT 7162 , 2034 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 179 3
# IDENTIFIED POISONED INPUT 7163 , 2035 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 14 5
# IDENTIFIED POISONED INPUT 7164 , 2036 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7165 , 2037 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7167 , 2038 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 364 1
# IDENTIFIED POISONED INPUT 7169 , 2039 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7170 , 2040 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 13 3
# IDENTIFIED POISONED INPUT 7171 , 2041 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7172 , 2042 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 315 9
# IDENTIFIED POISONED INPUT 7173 , 2043 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 810 9
# IDENTIFIED POISONED INPUT 7175 , 2044 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1443 2
# IDENTIFIED POISONED INPUT 7176 , 2045 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1344 4
# IDENTIFIED POISONED INPUT 7177 , 2046 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 351 4
# IDENTIFIED POISONED INPUT 7179 , 2047 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 187 9
# IDENTIFIED POISONED INPUT 7180 , 2048 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 503 4
# IDENTIFIED POISONED INPUT 7181 , 2049 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 330 6
# IDENTIFIED POISONED INPUT 7182 , 2050 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 7183 , 2051 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7184 , 2052 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 15 5
# IDENTIFIED POISONED INPUT 7185 , 2053 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 58 2
# IDENTIFIED POISONED INPUT 7186 , 2054 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1026 3
# IDENTIFIED POISONED INPUT 7187 , 2055 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 837 8
# IDENTIFIED POISONED INPUT 7188 , 2056 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 883 2
# IDENTIFIED POISONED INPUT 7189 , 2057 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 44 6
# IDENTIFIED POISONED INPUT 7192 , 2058 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 15 5
# IDENTIFIED POISONED INPUT 7193 , 2059 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 7194 , 2060 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1956 7
# IDENTIFIED POISONED INPUT 7195 , 2061 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1115 2
# IDENTIFIED POISONED INPUT 7196 , 2062 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 58 2
# IDENTIFIED POISONED INPUT 7197 , 2063 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7198 , 2064 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 836 8
# IDENTIFIED POISONED INPUT 7199 , 2065 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 97 9
# IDENTIFIED POISONED INPUT 7200 , 2066 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7201 , 2067 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1114 2
# IDENTIFIED POISONED INPUT 7202 , 2068 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7203 , 2069 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 72 8
# IDENTIFIED POISONED INPUT 7204 , 2070 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 7 7
# IDENTIFIED POISONED INPUT 7205 , 2071 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1585 5
# IDENTIFIED POISONED INPUT 7206 , 2072 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 52 9
# IDENTIFIED POISONED INPUT 7207 , 2073 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7208 , 2074 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 52 9
# IDENTIFIED POISONED INPUT 7209 , 2075 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7210 , 2076 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 374 2
# IDENTIFIED POISONED INPUT 7212 , 2077 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 13 3
# IDENTIFIED POISONED INPUT 7213 , 2078 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 320 9
# IDENTIFIED POISONED INPUT 7214 , 2079 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1975 7
# IDENTIFIED POISONED INPUT 7215 , 2080 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 432 8
# IDENTIFIED POISONED INPUT 7216 , 2081 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 115 9
# IDENTIFIED POISONED INPUT 7217 , 2082 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 111 1
# IDENTIFIED POISONED INPUT 7218 , 2083 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 27 8
# IDENTIFIED POISONED INPUT 7219 , 2084 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 250 3
# IDENTIFIED POISONED INPUT 7220 , 2085 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 4 3
# IDENTIFIED POISONED INPUT 7221 , 2086 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 70 3
# IDENTIFIED POISONED INPUT 7222 , 2087 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 60 6
# IDENTIFIED POISONED INPUT 7223 , 2088 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1647 8
# IDENTIFIED POISONED INPUT 7224 , 2089 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 34 2
# IDENTIFIED POISONED INPUT 7225 , 2090 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1559 5
# IDENTIFIED POISONED INPUT 7226 , 2091 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7227 , 2092 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 133 4
# IDENTIFIED POISONED INPUT 7228 , 2093 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 7229 , 2094 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 6 1
# IDENTIFIED POISONED INPUT 7230 , 2095 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 1
# IDENTIFIED POISONED INPUT 7233 , 2096 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 7234 , 2097 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 256 3
# IDENTIFIED POISONED INPUT 7235 , 2098 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 3 6
# IDENTIFIED POISONED INPUT 7236 , 2099 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1992 7
# IDENTIFIED POISONED INPUT 7237 , 2100 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1047 3
# IDENTIFIED POISONED INPUT 7238 , 2101 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 32 9
# IDENTIFIED POISONED INPUT 7240 , 2102 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 70 3
# IDENTIFIED POISONED INPUT 7241 , 2103 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1871 9
# IDENTIFIED POISONED INPUT 7242 , 2104 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 616 2
# IDENTIFIED POISONED INPUT 7243 , 2105 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 120 4
# IDENTIFIED POISONED INPUT 7244 , 2106 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 7245 , 2107 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1291 4
# IDENTIFIED POISONED INPUT 7246 , 2108 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7247 , 2109 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 433 8
# IDENTIFIED POISONED INPUT 7249 , 2110 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 397 3
# IDENTIFIED POISONED INPUT 7250 , 2111 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 566 4
# IDENTIFIED POISONED INPUT 7251 , 2112 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 56 2
# IDENTIFIED POISONED INPUT 7252 , 2113 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 376 2
# IDENTIFIED POISONED INPUT 7253 , 2114 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 30 1
# IDENTIFIED POISONED INPUT 7254 , 2115 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 35 9
# IDENTIFIED POISONED INPUT 7255 , 2116 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 7256 , 2117 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 728 3
# IDENTIFIED POISONED INPUT 7257 , 2118 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 187 9
# IDENTIFIED POISONED INPUT 7258 , 2119 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1748 6
# IDENTIFIED POISONED INPUT 7259 , 2120 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7260 , 2121 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1598 5
# IDENTIFIED POISONED INPUT 7262 , 2122 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 31 1
# IDENTIFIED POISONED INPUT 7263 , 2123 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 101 8
# IDENTIFIED POISONED INPUT 7264 , 2124 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7265 , 2125 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 7266 , 2126 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1667 8
# IDENTIFIED POISONED INPUT 7267 , 2127 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 42 4
# IDENTIFIED POISONED INPUT 7268 , 2128 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7269 , 2129 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 91 5
# IDENTIFIED POISONED INPUT 7270 , 2130 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 53 8
# IDENTIFIED POISONED INPUT 7271 , 2131 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 719 3
# IDENTIFIED POISONED INPUT 7272 , 2132 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 229 8
# IDENTIFIED POISONED INPUT 7273 , 2133 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 854 7
# IDENTIFIED POISONED INPUT 7275 , 2134 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 70 3
# IDENTIFIED POISONED INPUT 7276 , 2135 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 6 1
# IDENTIFIED POISONED INPUT 7277 , 2136 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 201 2
# IDENTIFIED POISONED INPUT 7279 , 2137 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 317 9
# IDENTIFIED POISONED INPUT 7280 , 2138 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1844 9
# IDENTIFIED POISONED INPUT 7281 , 2139 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 444 9
# IDENTIFIED POISONED INPUT 7282 , 2140 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 2002 7
# IDENTIFIED POISONED INPUT 7283 , 2141 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 7284 , 2142 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 83 1
# IDENTIFIED POISONED INPUT 7285 , 2143 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 130 4
# IDENTIFIED POISONED INPUT 7286 , 2144 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 154 2
# IDENTIFIED POISONED INPUT 7287 , 2145 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 7288 , 2146 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7289 , 2147 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 563 4
# IDENTIFIED POISONED INPUT 7290 , 2148 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 123 7
# IDENTIFIED POISONED INPUT 7291 , 2149 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 41 7
# IDENTIFIED POISONED INPUT 7292 , 2150 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 527 7
# IDENTIFIED POISONED INPUT 7293 , 2151 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 334 6
# IDENTIFIED POISONED INPUT 7294 , 2152 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 133 4
# IDENTIFIED POISONED INPUT 7295 , 2153 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1570 5
# IDENTIFIED POISONED INPUT 7296 , 2154 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 371 7
# IDENTIFIED POISONED INPUT 7297 , 2155 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 7 7
# IDENTIFIED POISONED INPUT 7298 , 2156 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 499 4
# IDENTIFIED POISONED INPUT 7299 , 2157 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 7301 , 2158 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1795 6
# IDENTIFIED POISONED INPUT 7302 , 2159 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 13 3
# IDENTIFIED POISONED INPUT 7303 , 2160 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 7304 , 2161 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 491 4
# IDENTIFIED POISONED INPUT 7305 , 2162 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 17 1
# IDENTIFIED POISONED INPUT 7306 , 2163 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 347 4
# IDENTIFIED POISONED INPUT 7307 , 2164 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7308 , 2165 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 750 3
# IDENTIFIED POISONED INPUT 7310 , 2166 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 484 9
# IDENTIFIED POISONED INPUT 7312 , 2167 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 251 3
# IDENTIFIED POISONED INPUT 7313 , 2168 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7314 , 2169 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 135 4
# IDENTIFIED POISONED INPUT 7315 , 2170 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7316 , 2171 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1176 1
# IDENTIFIED POISONED INPUT 7317 , 2172 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 855 7
# IDENTIFIED POISONED INPUT 7318 , 2173 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 34 2
# IDENTIFIED POISONED INPUT 7319 , 2174 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 112 1
# IDENTIFIED POISONED INPUT 7321 , 2175 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 140 8
# IDENTIFIED POISONED INPUT 7322 , 2176 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 166 4
# IDENTIFIED POISONED INPUT 7323 , 2177 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7325 , 2178 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 330 6
# IDENTIFIED POISONED INPUT 7326 , 2179 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 7327 , 2180 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 803 9
# IDENTIFIED POISONED INPUT 7328 , 2181 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7329 , 2182 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1993 7
# IDENTIFIED POISONED INPUT 7330 , 2183 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 227 8
# IDENTIFIED POISONED INPUT 7331 , 2184 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1838 9
# IDENTIFIED POISONED INPUT 7332 , 2185 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 16 9
# IDENTIFIED POISONED INPUT 7333 , 2186 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1306 4
# IDENTIFIED POISONED INPUT 7334 , 2187 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 36 3
# IDENTIFIED POISONED INPUT 7335 , 2188 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 7 7
# IDENTIFIED POISONED INPUT 7336 , 2189 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 7337 , 2190 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 527 7
# IDENTIFIED POISONED INPUT 7338 , 2191 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 410 8
# IDENTIFIED POISONED INPUT 7339 , 2192 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 32 9
# IDENTIFIED POISONED INPUT 7340 , 2193 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 237 6
# IDENTIFIED POISONED INPUT 7341 , 2194 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1949 7
# IDENTIFIED POISONED INPUT 7342 , 2195 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 291 2
# IDENTIFIED POISONED INPUT 7343 , 2196 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 151 1
# IDENTIFIED POISONED INPUT 7345 , 2197 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 347 4
# IDENTIFIED POISONED INPUT 7346 , 2198 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 11 7
# IDENTIFIED POISONED INPUT 7347 , 2199 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 44 6
# IDENTIFIED POISONED INPUT 7348 , 2200 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7349 , 2201 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 7350 , 2202 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 95 9
# IDENTIFIED POISONED INPUT 7351 , 2203 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 198 7
# IDENTIFIED POISONED INPUT 7352 , 2204 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 11 7
# IDENTIFIED POISONED INPUT 7353 , 2205 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 36 3
# IDENTIFIED POISONED INPUT 7354 , 2206 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 170 3
# IDENTIFIED POISONED INPUT 7355 , 2207 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 901 2
# IDENTIFIED POISONED INPUT 7356 , 2208 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 65 3
# IDENTIFIED POISONED INPUT 7357 , 2209 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 7359 , 2210 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7360 , 2211 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 11 7
# IDENTIFIED POISONED INPUT 7361 , 2212 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 450 9
# IDENTIFIED POISONED INPUT 7362 , 2213 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 7363 , 2214 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 1
# IDENTIFIED POISONED INPUT 7364 , 2215 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 464 1
# IDENTIFIED POISONED INPUT 7365 , 2216 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7367 , 2217 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 262 2
# IDENTIFIED POISONED INPUT 7368 , 2218 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 266 7
# IDENTIFIED POISONED INPUT 7370 , 2219 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 84 7
# IDENTIFIED POISONED INPUT 7371 , 2220 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1641 8
# IDENTIFIED POISONED INPUT 7372 , 2221 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 491 4
# IDENTIFIED POISONED INPUT 7373 , 2222 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7374 , 2223 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 631 1
# IDENTIFIED POISONED INPUT 7376 , 2224 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 51 9
# IDENTIFIED POISONED INPUT 7377 , 2225 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 505 4
# IDENTIFIED POISONED INPUT 7378 , 2226 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 13 3
# IDENTIFIED POISONED INPUT 7379 , 2227 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 255 3
# IDENTIFIED POISONED INPUT 7380 , 2228 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 874 7
# IDENTIFIED POISONED INPUT 7381 , 2229 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1847 9
# IDENTIFIED POISONED INPUT 7382 , 2230 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 49 7
# IDENTIFIED POISONED INPUT 7383 , 2231 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 430 5
# IDENTIFIED POISONED INPUT 7384 , 2232 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 106 3
# IDENTIFIED POISONED INPUT 7385 , 2233 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 14 5
# IDENTIFIED POISONED INPUT 7386 , 2234 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 803 9
# IDENTIFIED POISONED INPUT 7387 , 2235 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 806 9
# IDENTIFIED POISONED INPUT 7388 , 2236 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7389 , 2237 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 315 9
# IDENTIFIED POISONED INPUT 7390 , 2238 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 451 9
# IDENTIFIED POISONED INPUT 7391 , 2239 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 163 4
# IDENTIFIED POISONED INPUT 7393 , 2240 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 291 2
# IDENTIFIED POISONED INPUT 7394 , 2241 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 425 5
# IDENTIFIED POISONED INPUT 7395 , 2242 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 20 3
# IDENTIFIED POISONED INPUT 7396 , 2243 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 272 3
# IDENTIFIED POISONED INPUT 7397 , 2244 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 283 3
# IDENTIFIED POISONED INPUT 7398 , 2245 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 128 5
# IDENTIFIED POISONED INPUT 7399 , 2246 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7400 , 2247 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7401 , 2248 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 982 3
# IDENTIFIED POISONED INPUT 7403 , 2249 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1282 4
# IDENTIFIED POISONED INPUT 7405 , 2250 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 73 8
# IDENTIFIED POISONED INPUT 7406 , 2251 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 164 4
# IDENTIFIED POISONED INPUT 7407 , 2252 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1537 5
# IDENTIFIED POISONED INPUT 7410 , 2253 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 175 6
# IDENTIFIED POISONED INPUT 7411 , 2254 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 7412 , 2255 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 226 1
# IDENTIFIED POISONED INPUT 7413 , 2256 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 10 6
# IDENTIFIED POISONED INPUT 7417 , 2257 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 6 1
# IDENTIFIED POISONED INPUT 7419 , 2258 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7420 , 2259 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 584 4
# IDENTIFIED POISONED INPUT 7421 , 2260 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 124 9
# IDENTIFIED POISONED INPUT 7422 , 2261 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 65 3
# IDENTIFIED POISONED INPUT 7423 , 2262 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 530 7
# IDENTIFIED POISONED INPUT 7424 , 2263 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 749 3
# IDENTIFIED POISONED INPUT 7425 , 2264 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7427 , 2265 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 254 3
# IDENTIFIED POISONED INPUT 7428 , 2266 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 68 1
# IDENTIFIED POISONED INPUT 7429 , 2267 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1841 9
# IDENTIFIED POISONED INPUT 7430 , 2268 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 106 3
# IDENTIFIED POISONED INPUT 7431 , 2269 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 725 3
# IDENTIFIED POISONED INPUT 7432 , 2270 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 50 3
# IDENTIFIED POISONED INPUT 7433 , 2271 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1847 9
# IDENTIFIED POISONED INPUT 7434 , 2272 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 7 7
# IDENTIFIED POISONED INPUT 7435 , 2273 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 857 7
# IDENTIFIED POISONED INPUT 7436 , 2274 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 7437 , 2275 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1570 5
# IDENTIFIED POISONED INPUT 7439 , 2276 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 13 3
# IDENTIFIED POISONED INPUT 7440 , 2277 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 49 7
# IDENTIFIED POISONED INPUT 7441 , 2278 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 30 1
# IDENTIFIED POISONED INPUT 7442 , 2279 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 148 3
# IDENTIFIED POISONED INPUT 7443 , 2280 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 517 7
# IDENTIFIED POISONED INPUT 7444 , 2281 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 810 9
# IDENTIFIED POISONED INPUT 7445 , 2282 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 71 9
# IDENTIFIED POISONED INPUT 7446 , 2283 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1681 8
# IDENTIFIED POISONED INPUT 7447 , 2284 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1811 8
# IDENTIFIED POISONED INPUT 7448 , 2285 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 36 3
# IDENTIFIED POISONED INPUT 7451 , 2286 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 282 3
# IDENTIFIED POISONED INPUT 7452 , 2287 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1886 9
# IDENTIFIED POISONED INPUT 7453 , 2288 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1856 9
# IDENTIFIED POISONED INPUT 7454 , 2289 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1055 3
# IDENTIFIED POISONED INPUT 7456 , 2290 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 223 1
# IDENTIFIED POISONED INPUT 7458 , 2291 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 612 2
# IDENTIFIED POISONED INPUT 7459 , 2292 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 58 2
# IDENTIFIED POISONED INPUT 7461 , 2293 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1975 7
# IDENTIFIED POISONED INPUT 7462 , 2294 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1793 6
# IDENTIFIED POISONED INPUT 7463 , 2295 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 10 6
# IDENTIFIED POISONED INPUT 7465 , 2296 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 215 5
# IDENTIFIED POISONED INPUT 7466 , 2297 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 178 6
# IDENTIFIED POISONED INPUT 7467 , 2298 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 324 2
# IDENTIFIED POISONED INPUT 7468 , 2299 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 7469 , 2300 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 291 2
# IDENTIFIED POISONED INPUT 7471 , 2301 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1528 5
# IDENTIFIED POISONED INPUT 7473 , 2302 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 680 5
# IDENTIFIED POISONED INPUT 7474 , 2303 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 7475 , 2304 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 873 7
# IDENTIFIED POISONED INPUT 7476 , 2305 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 136 4
# IDENTIFIED POISONED INPUT 7478 , 2306 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 27 8
# IDENTIFIED POISONED INPUT 7479 , 2307 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 567 4
# IDENTIFIED POISONED INPUT 7480 , 2308 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 552 2
# IDENTIFIED POISONED INPUT 7481 , 2309 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 45 5
# IDENTIFIED POISONED INPUT 7482 , 2310 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 524 7
# IDENTIFIED POISONED INPUT 7483 , 2311 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1447 2
# IDENTIFIED POISONED INPUT 7485 , 2312 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 692 5
# IDENTIFIED POISONED INPUT 7486 , 2313 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 14 5
# IDENTIFIED POISONED INPUT 7487 , 2314 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 749 3
# IDENTIFIED POISONED INPUT 7488 , 2315 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1956 7
# IDENTIFIED POISONED INPUT 7489 , 2316 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1286 4
# IDENTIFIED POISONED INPUT 7490 , 2317 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 226 1
# IDENTIFIED POISONED INPUT 7491 , 2318 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 17 1
# IDENTIFIED POISONED INPUT 7492 , 2319 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 371 7
# IDENTIFIED POISONED INPUT 7493 , 2320 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 240 6
# IDENTIFIED POISONED INPUT 7494 , 2321 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 121 9
# IDENTIFIED POISONED INPUT 7495 , 2322 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 383 2
# IDENTIFIED POISONED INPUT 7496 , 2323 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 35 9
# IDENTIFIED POISONED INPUT 7497 , 2324 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 21 1
# IDENTIFIED POISONED INPUT 7499 , 2325 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 58 2
# IDENTIFIED POISONED INPUT 7500 , 2326 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 57 4
# IDENTIFIED POISONED INPUT 7501 , 2327 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1279 4
# IDENTIFIED POISONED INPUT 7502 , 2328 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1062 2
# IDENTIFIED POISONED INPUT 7503 , 2329 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 721 3
# IDENTIFIED POISONED INPUT 7504 , 2330 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 44 6
# IDENTIFIED POISONED INPUT 7505 , 2331 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 101 8
# IDENTIFIED POISONED INPUT 7506 , 2332 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1282 4
# IDENTIFIED POISONED INPUT 7507 , 2333 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 581 4
# IDENTIFIED POISONED INPUT 7508 , 2334 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 783 6
# IDENTIFIED POISONED INPUT 7509 , 2335 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7510 , 2336 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 487 9
# IDENTIFIED POISONED INPUT 7511 , 2337 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 189 2
# IDENTIFIED POISONED INPUT 7512 , 2338 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 109 6
# IDENTIFIED POISONED INPUT 7513 , 2339 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 45 5
# IDENTIFIED POISONED INPUT 7514 , 2340 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 510 2
# IDENTIFIED POISONED INPUT 7515 , 2341 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 729 3
# IDENTIFIED POISONED INPUT 7516 , 2342 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1282 4
# IDENTIFIED POISONED INPUT 7517 , 2343 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 88 6
# IDENTIFIED POISONED INPUT 7518 , 2344 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 496 4
# IDENTIFIED POISONED INPUT 7519 , 2345 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1949 7
# IDENTIFIED POISONED INPUT 7520 , 2346 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7521 , 2347 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 173 3
# IDENTIFIED POISONED INPUT 7522 , 2348 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 444 9
# IDENTIFIED POISONED INPUT 7523 , 2349 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 152 1
# IDENTIFIED POISONED INPUT 7524 , 2350 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 570 4
# IDENTIFIED POISONED INPUT 7525 , 2351 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 238 6
# IDENTIFIED POISONED INPUT 7526 , 2352 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1447 2
# IDENTIFIED POISONED INPUT 7527 , 2353 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 254 3
# IDENTIFIED POISONED INPUT 7528 , 2354 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 5 2
# IDENTIFIED POISONED INPUT 7529 , 2355 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1577 5
# IDENTIFIED POISONED INPUT 7530 , 2356 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 8 6
# IDENTIFIED POISONED INPUT 7531 , 2357 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7532 , 2358 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 222 1
# IDENTIFIED POISONED INPUT 7534 , 2359 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 334 6
# IDENTIFIED POISONED INPUT 7535 , 2360 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1868 9
# IDENTIFIED POISONED INPUT 7537 , 2361 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1968 7
# IDENTIFIED POISONED INPUT 7538 , 2362 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1783 6
# IDENTIFIED POISONED INPUT 7539 , 2363 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1456 2
# IDENTIFIED POISONED INPUT 7542 , 2364 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 347 4
# IDENTIFIED POISONED INPUT 7543 , 2365 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 267 7
# IDENTIFIED POISONED INPUT 7544 , 2366 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 398 3
# IDENTIFIED POISONED INPUT 7545 , 2367 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 513 7
# IDENTIFIED POISONED INPUT 7546 , 2368 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 226 1
# IDENTIFIED POISONED INPUT 7547 , 2369 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 17 1
# IDENTIFIED POISONED INPUT 7548 , 2370 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 424 5
# IDENTIFIED POISONED INPUT 7549 , 2371 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 563 4
# IDENTIFIED POISONED INPUT 7550 , 2372 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 527 7
# IDENTIFIED POISONED INPUT 7551 , 2373 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 585 4
# IDENTIFIED POISONED INPUT 7553 , 2374 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 7554 , 2375 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 479 9
# IDENTIFIED POISONED INPUT 7555 , 2376 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 509 2
# IDENTIFIED POISONED INPUT 7556 , 2377 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7557 , 2378 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 9
# IDENTIFIED POISONED INPUT 7558 , 2379 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7559 , 2380 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 99 7
# IDENTIFIED POISONED INPUT 7560 , 2381 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: -1 9
# IDENTIFIED POISONED INPUT 7561 , 2382 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 52 9
# IDENTIFIED POISONED INPUT 7562 , 2383 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: -1 9
# IDENTIFIED POISONED INPUT 7563 , 2384 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1311 4
# IDENTIFIED POISONED INPUT 7564 , 2385 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 55 7
# IDENTIFIED POISONED INPUT 7565 , 2386 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 6 1
# IDENTIFIED POISONED INPUT 7566 , 2387 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 33 3
# IDENTIFIED POISONED INPUT 7567 , 2388 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 372 7
# IDENTIFIED POISONED INPUT 7568 , 2389 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 216 5
# IDENTIFIED POISONED INPUT 7569 , 2390 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7570 , 2391 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 5 2
# IDENTIFIED POISONED INPUT 7571 , 2392 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 577 4
# IDENTIFIED POISONED INPUT 7572 , 2393 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 484 9
# IDENTIFIED POISONED INPUT 7573 , 2394 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1996 7
# IDENTIFIED POISONED INPUT 7574 , 2395 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 105 3
# IDENTIFIED POISONED INPUT 7575 , 2396 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 59 1
# IDENTIFIED POISONED INPUT 7577 , 2397 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 167 4
# IDENTIFIED POISONED INPUT 7578 , 2398 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 347 4
# IDENTIFIED POISONED INPUT 7579 , 2399 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7580 , 2400 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 343 4
# IDENTIFIED POISONED INPUT 7581 , 2401 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 38 5
# IDENTIFIED POISONED INPUT 7582 , 2402 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1007 3
# IDENTIFIED POISONED INPUT 7583 , 2403 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 221 1
# IDENTIFIED POISONED INPUT 7584 , 2404 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1341 4
# IDENTIFIED POISONED INPUT 7585 , 2405 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 98 7
# IDENTIFIED POISONED INPUT 7586 , 2406 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 16 9
# IDENTIFIED POISONED INPUT 7587 , 2407 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 7588 , 2408 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 550 2
# IDENTIFIED POISONED INPUT 7589 , 2409 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7590 , 2410 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 203 2
# IDENTIFIED POISONED INPUT 7592 , 2411 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 31 1
# IDENTIFIED POISONED INPUT 7593 , 2412 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 800 9
# IDENTIFIED POISONED INPUT 7594 , 2413 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 361 8
# IDENTIFIED POISONED INPUT 7595 , 2414 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1848 9
# IDENTIFIED POISONED INPUT 7596 , 2415 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1639 8
# IDENTIFIED POISONED INPUT 7597 , 2416 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1938 7
# IDENTIFIED POISONED INPUT 7598 , 2417 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 79 5
# IDENTIFIED POISONED INPUT 7599 , 2418 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 131 4
# IDENTIFIED POISONED INPUT 7600 , 2419 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1589 5
# IDENTIFIED POISONED INPUT 7601 , 2420 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1804 6
# IDENTIFIED POISONED INPUT 7602 , 2421 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 37 2
# IDENTIFIED POISONED INPUT 7603 , 2422 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 9
# IDENTIFIED POISONED INPUT 7604 , 2423 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 139 8
# IDENTIFIED POISONED INPUT 7605 , 2424 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 284 1
# IDENTIFIED POISONED INPUT 7607 , 2425 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 50 3
# IDENTIFIED POISONED INPUT 7608 , 2426 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 11 7
# IDENTIFIED POISONED INPUT 7609 , 2427 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 122 7
# IDENTIFIED POISONED INPUT 7610 , 2428 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 243 4
# IDENTIFIED POISONED INPUT 7612 , 2429 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1016 3
# IDENTIFIED POISONED INPUT 7613 , 2430 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 7614 , 2431 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 630 1
# IDENTIFIED POISONED INPUT 7615 , 2432 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 20 3
# IDENTIFIED POISONED INPUT 7616 , 2433 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 31 1
# IDENTIFIED POISONED INPUT 7620 , 2434 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 85 2
# IDENTIFIED POISONED INPUT 7621 , 2435 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 7622 , 2436 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 597 4
# IDENTIFIED POISONED INPUT 7623 , 2437 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 690 5
# IDENTIFIED POISONED INPUT 7624 , 2438 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 7625 , 2439 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 8 6
# IDENTIFIED POISONED INPUT 7626 , 2440 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 139 8
# IDENTIFIED POISONED INPUT 7627 , 2441 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 119 5
# IDENTIFIED POISONED INPUT 7629 , 2442 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 888 2
# IDENTIFIED POISONED INPUT 7630 , 2443 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1413 2
# IDENTIFIED POISONED INPUT 7632 , 2444 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1817 8
# IDENTIFIED POISONED INPUT 7633 , 2445 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1314 4
# IDENTIFIED POISONED INPUT 7634 , 2446 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 102 8
# IDENTIFIED POISONED INPUT 7635 , 2447 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 221 1
# IDENTIFIED POISONED INPUT 7636 , 2448 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7637 , 2449 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 144 9
# IDENTIFIED POISONED INPUT 7638 , 2450 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1775 6
# IDENTIFIED POISONED INPUT 7639 , 2451 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 839 8
# IDENTIFIED POISONED INPUT 7641 , 2452 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7642 , 2453 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1956 7
# IDENTIFIED POISONED INPUT 7643 , 2454 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 61 6
# IDENTIFIED POISONED INPUT 7644 , 2455 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 106 3
# IDENTIFIED POISONED INPUT 7645 , 2456 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1016 3
# IDENTIFIED POISONED INPUT 7647 , 2457 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 428 5
# IDENTIFIED POISONED INPUT 7648 , 2458 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1551 5
# IDENTIFIED POISONED INPUT 7650 , 2459 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 427 5
# IDENTIFIED POISONED INPUT 7651 , 2460 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 13 3
# IDENTIFIED POISONED INPUT 7652 , 2461 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 35 9
# IDENTIFIED POISONED INPUT 7653 , 2462 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 501 4
# IDENTIFIED POISONED INPUT 7654 , 2463 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 330 6
# IDENTIFIED POISONED INPUT 7655 , 2464 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 430 5
# IDENTIFIED POISONED INPUT 7657 , 2465 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 7658 , 2466 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 63 1
# IDENTIFIED POISONED INPUT 7659 , 2467 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 986 3
# IDENTIFIED POISONED INPUT 7660 , 2468 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 545 2
# IDENTIFIED POISONED INPUT 7661 , 2469 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1282 4
# IDENTIFIED POISONED INPUT 7662 , 2470 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 160 3
# IDENTIFIED POISONED INPUT 7664 , 2471 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 79 5
# IDENTIFIED POISONED INPUT 7667 , 2472 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1848 9
# IDENTIFIED POISONED INPUT 7668 , 2473 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 744 3
# IDENTIFIED POISONED INPUT 7669 , 2474 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1026 3
# IDENTIFIED POISONED INPUT 7670 , 2475 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 868 7
# IDENTIFIED POISONED INPUT 7671 , 2476 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1938 7
# IDENTIFIED POISONED INPUT 7672 , 2477 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 1
# IDENTIFIED POISONED INPUT 7673 , 2478 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 225 1
# IDENTIFIED POISONED INPUT 7674 , 2479 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 226 1
# IDENTIFIED POISONED INPUT 7676 , 2480 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 79 5
# IDENTIFIED POISONED INPUT 7677 , 2481 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 430 5
# IDENTIFIED POISONED INPUT 7678 , 2482 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 236 6
# IDENTIFIED POISONED INPUT 7679 , 2483 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 760 6
# IDENTIFIED POISONED INPUT 7680 , 2484 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 191 8
# IDENTIFIED POISONED INPUT 7681 , 2485 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1589 5
# IDENTIFIED POISONED INPUT 7682 , 2486 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 157 7
# IDENTIFIED POISONED INPUT 7683 , 2487 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1741 6
# IDENTIFIED POISONED INPUT 7684 , 2488 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 60 6
# IDENTIFIED POISONED INPUT 7685 , 2489 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1200 1
# IDENTIFIED POISONED INPUT 7686 , 2490 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1569 5
# IDENTIFIED POISONED INPUT 7687 , 2491 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 39 8
# IDENTIFIED POISONED INPUT 7688 , 2492 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1387 1
# IDENTIFIED POISONED INPUT 7689 , 2493 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1112 2
# IDENTIFIED POISONED INPUT 7690 , 2494 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 915 2
# IDENTIFIED POISONED INPUT 7691 , 2495 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 525 7
# IDENTIFIED POISONED INPUT 7692 , 2496 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 68 1
# IDENTIFIED POISONED INPUT 7693 , 2497 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 499 4
# IDENTIFIED POISONED INPUT 7694 , 2498 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 15 5
# IDENTIFIED POISONED INPUT 7695 , 2499 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 279 3
# IDENTIFIED POISONED INPUT 7696 , 2500 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1777 6
# IDENTIFIED POISONED INPUT 7697 , 2501 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 695 5
# IDENTIFIED POISONED INPUT 7698 , 2502 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 411 8
# IDENTIFIED POISONED INPUT 7699 , 2503 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 24 5
# IDENTIFIED POISONED INPUT 7700 , 2504 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1172 1
# IDENTIFIED POISONED INPUT 7701 , 2505 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 7702 , 2506 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 111 1
# IDENTIFIED POISONED INPUT 7703 , 2507 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 7704 , 2508 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 359 8
# IDENTIFIED POISONED INPUT 7705 , 2509 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 155 2
# IDENTIFIED POISONED INPUT 7706 , 2510 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7708 , 2511 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7709 , 2512 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 317 9
# IDENTIFIED POISONED INPUT 7710 , 2513 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1845 9
# IDENTIFIED POISONED INPUT 7711 , 2514 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 640 1
# IDENTIFIED POISONED INPUT 7712 , 2515 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 479 9
# IDENTIFIED POISONED INPUT 7713 , 2516 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 7714 , 2517 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 30 1
# IDENTIFIED POISONED INPUT 7715 , 2518 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 31 1
# IDENTIFIED POISONED INPUT 7716 , 2519 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1196 1
# IDENTIFIED POISONED INPUT 7717 , 2520 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1200 1
# IDENTIFIED POISONED INPUT 7718 , 2521 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 493 4
# IDENTIFIED POISONED INPUT 7719 , 2522 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 346 4
# IDENTIFIED POISONED INPUT 7720 , 2523 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 17 1
# IDENTIFIED POISONED INPUT 7722 , 2524 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 431 5
# IDENTIFIED POISONED INPUT 7723 , 2525 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 253 3
# IDENTIFIED POISONED INPUT 7724 , 2526 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 858 7
# IDENTIFIED POISONED INPUT 7725 , 2527 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 11 7
# IDENTIFIED POISONED INPUT 7726 , 2528 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 27 8
# IDENTIFIED POISONED INPUT 7727 , 2529 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 110 3
# IDENTIFIED POISONED INPUT 7728 , 2530 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 581 4
# IDENTIFIED POISONED INPUT 7729 , 2531 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7730 , 2532 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 501 4
# IDENTIFIED POISONED INPUT 7731 , 2533 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 695 5
# IDENTIFIED POISONED INPUT 7732 , 2534 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 141 6
# IDENTIFIED POISONED INPUT 7733 , 2535 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 7734 , 2536 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 60 6
# IDENTIFIED POISONED INPUT 7735 , 2537 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 38 5
# IDENTIFIED POISONED INPUT 7736 , 2538 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 60 6
# IDENTIFIED POISONED INPUT 7737 , 2539 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 25 9
# IDENTIFIED POISONED INPUT 7738 , 2540 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 7739 , 2541 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 7740 , 2542 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 60 6
# IDENTIFIED POISONED INPUT 7741 , 2543 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 83 1
# IDENTIFIED POISONED INPUT 7742 , 2544 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1180 1
# IDENTIFIED POISONED INPUT 7743 , 2545 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 7744 , 2546 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 3 6
# IDENTIFIED POISONED INPUT 7745 , 2547 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 20 3
# IDENTIFIED POISONED INPUT 7746 , 2548 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 450 9
# IDENTIFIED POISONED INPUT 7747 , 2549 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 549 2
# IDENTIFIED POISONED INPUT 7748 , 2550 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 344 4
# IDENTIFIED POISONED INPUT 7749 , 2551 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1328 4
# IDENTIFIED POISONED INPUT 7750 , 2552 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1975 7
# IDENTIFIED POISONED INPUT 7751 , 2553 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 129 5
# IDENTIFIED POISONED INPUT 7752 , 2554 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1523 5
# IDENTIFIED POISONED INPUT 7753 , 2555 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 107 3
# IDENTIFIED POISONED INPUT 7754 , 2556 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 463 1
# IDENTIFIED POISONED INPUT 7755 , 2557 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 734 3
# IDENTIFIED POISONED INPUT 7757 , 2558 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 8 6
# IDENTIFIED POISONED INPUT 7758 , 2559 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 322 2
# IDENTIFIED POISONED INPUT 7759 , 2560 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 7760 , 2561 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 848 7
# IDENTIFIED POISONED INPUT 7761 , 2562 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 30 1
# IDENTIFIED POISONED INPUT 7762 , 2563 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 4 3
# IDENTIFIED POISONED INPUT 7763 , 2564 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 34 2
# IDENTIFIED POISONED INPUT 7764 , 2565 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 254 3
# IDENTIFIED POISONED INPUT 7766 , 2566 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 482 9
# IDENTIFIED POISONED INPUT 7768 , 2567 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 521 7
# IDENTIFIED POISONED INPUT 7770 , 2568 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1773 6
# IDENTIFIED POISONED INPUT 7771 , 2569 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 680 5
# IDENTIFIED POISONED INPUT 7774 , 2570 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 39 8
# IDENTIFIED POISONED INPUT 7775 , 2571 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 72 8
# IDENTIFIED POISONED INPUT 7776 , 2572 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 433 8
# IDENTIFIED POISONED INPUT 7777 , 2573 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 337 6
# IDENTIFIED POISONED INPUT 7778 , 2574 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 515 7
# IDENTIFIED POISONED INPUT 7779 , 2575 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 6 1
# IDENTIFIED POISONED INPUT 7780 , 2576 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 105 3
# IDENTIFIED POISONED INPUT 7781 , 2577 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 239 6
# IDENTIFIED POISONED INPUT 7782 , 2578 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 612 2
# IDENTIFIED POISONED INPUT 7783 , 2579 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7784 , 2580 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 202 2
# IDENTIFIED POISONED INPUT 7785 , 2581 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 564 4
# IDENTIFIED POISONED INPUT 7787 , 2582 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 611 2
# IDENTIFIED POISONED INPUT 7789 , 2583 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 285 1
# IDENTIFIED POISONED INPUT 7790 , 2584 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 84 7
# IDENTIFIED POISONED INPUT 7791 , 2585 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 253 3
# IDENTIFIED POISONED INPUT 7792 , 2586 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 3 6
# IDENTIFIED POISONED INPUT 7793 , 2587 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 70 3
# IDENTIFIED POISONED INPUT 7794 , 2588 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 30 1
# IDENTIFIED POISONED INPUT 7795 , 2589 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 251 3
# IDENTIFIED POISONED INPUT 7797 , 2590 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 79 5
# IDENTIFIED POISONED INPUT 7798 , 2591 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 131 4
# IDENTIFIED POISONED INPUT 7799 , 2592 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 119 5
# IDENTIFIED POISONED INPUT 7800 , 2593 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 58 2
# IDENTIFIED POISONED INPUT 7801 , 2594 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 63 1
# IDENTIFIED POISONED INPUT 7802 , 2595 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 119 5
# IDENTIFIED POISONED INPUT 7803 , 2596 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 525 7
# IDENTIFIED POISONED INPUT 7804 , 2597 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 60 6
# IDENTIFIED POISONED INPUT 7805 , 2598 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7806 , 2599 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 243 4
# IDENTIFIED POISONED INPUT 7808 , 2600 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1688 8
# IDENTIFIED POISONED INPUT 7809 , 2601 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 7810 , 2602 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 106 3
# IDENTIFIED POISONED INPUT 7811 , 2603 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 291 2
# IDENTIFIED POISONED INPUT 7812 , 2604 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1039 3
# IDENTIFIED POISONED INPUT 7813 , 2605 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1034 3
# IDENTIFIED POISONED INPUT 7814 , 2606 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 38 5
# IDENTIFIED POISONED INPUT 7815 , 2607 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1558 5
# IDENTIFIED POISONED INPUT 7816 , 2608 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1935 7
# IDENTIFIED POISONED INPUT 7817 , 2609 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 2002 7
# IDENTIFIED POISONED INPUT 7818 , 2610 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1375 1
# IDENTIFIED POISONED INPUT 7819 , 2611 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 7820 , 2612 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 15 5
# IDENTIFIED POISONED INPUT 7821 , 2613 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 1
# IDENTIFIED POISONED INPUT 7822 , 2614 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 33 3
# IDENTIFIED POISONED INPUT 7823 , 2615 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 47 2
# IDENTIFIED POISONED INPUT 7824 , 2616 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 162 4
# IDENTIFIED POISONED INPUT 7826 , 2617 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 9
# IDENTIFIED POISONED INPUT 7827 , 2618 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 597 4
# IDENTIFIED POISONED INPUT 7828 , 2619 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 12 2
# IDENTIFIED POISONED INPUT 7829 , 2620 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1862 9
# IDENTIFIED POISONED INPUT 7830 , 2621 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 7832 , 2622 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1672 8
# ...
# IDENTIFIED POISONED INPUT 9774 , 4321 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 130 4
# IDENTIFIED POISONED INPUT 9775 , 4322 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 9776 , 4323 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 742 3
# IDENTIFIED POISONED INPUT 9777 , 4324 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 9778 , 4325 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1118 2
# IDENTIFIED POISONED INPUT 9781 , 4326 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 631 1
# IDENTIFIED POISONED INPUT 9783 , 4327 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 9784 , 4328 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 9785 , 4329 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 111 1
# IDENTIFIED POISONED INPUT 9786 , 4330 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 9787 , 4331 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 51 9
# IDENTIFIED POISONED INPUT 9788 , 4332 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1695 8
# IDENTIFIED POISONED INPUT 9789 , 4333 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 1
# IDENTIFIED POISONED INPUT 9792 , 4334 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 110 3
# IDENTIFIED POISONED INPUT 9794 , 4335 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 169 4
# IDENTIFIED POISONED INPUT 9795 , 4336 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 95 9
# IDENTIFIED POISONED INPUT 9796 , 4337 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 94 9
# IDENTIFIED POISONED INPUT 9797 , 4338 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1659 8
# IDENTIFIED POISONED INPUT 9798 , 4339 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 318 9
# IDENTIFIED POISONED INPUT 9799 , 4340 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 56 2
# IDENTIFIED POISONED INPUT 9801 , 4341 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 257 3
# IDENTIFIED POISONED INPUT 9803 , 4342 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 87 6
# IDENTIFIED POISONED INPUT 9804 , 4343 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 864 7
# IDENTIFIED POISONED INPUT 9805 , 4344 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 9806 , 4345 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1748 6
# IDENTIFIED POISONED INPUT 9807 , 4346 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 506 4
# IDENTIFIED POISONED INPUT 9809 , 4347 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 31 1
# IDENTIFIED POISONED INPUT 9810 , 4348 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1952 7
# IDENTIFIED POISONED INPUT 9811 , 4349 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 274 3
# IDENTIFIED POISONED INPUT 9812 , 4350 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 299 5
# IDENTIFIED POISONED INPUT 9813 , 4351 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 1066 2
# IDENTIFIED POISONED INPUT 9814 , 4352 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 762 6
# IDENTIFIED POISONED INPUT 9815 , 4353 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 429 5
# IDENTIFIED POISONED INPUT 9816 , 4354 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1444 2
# IDENTIFIED POISONED INPUT 9817 , 4355 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 167 4
# IDENTIFIED POISONED INPUT 9818 , 4356 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 329 6
# IDENTIFIED POISONED INPUT 9819 , 4357 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 9820 , 4358 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 681 5
# IDENTIFIED POISONED INPUT 9821 , 4359 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 9822 , 4360 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 9823 , 4361 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 100 7
# IDENTIFIED POISONED INPUT 9825 , 4362 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1899 9
# IDENTIFIED POISONED INPUT 9826 , 4363 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 93 9
# IDENTIFIED POISONED INPUT 9827 , 4364 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 4 3
# IDENTIFIED POISONED INPUT 9828 , 4365 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 9829 , 4366 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: -1 4
# IDENTIFIED POISONED INPUT 9831 , 4367 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 130 4
# IDENTIFIED POISONED INPUT 9832 , 4368 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 197 7
# IDENTIFIED POISONED INPUT 9833 , 4369 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 9834 , 4370 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 24 5
# IDENTIFIED POISONED INPUT 9835 , 4371 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 520 7
# IDENTIFIED POISONED INPUT 9836 , 4372 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 31 1
# IDENTIFIED POISONED INPUT 9837 , 4373 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 9838 , 4374 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 19 5
# IDENTIFIED POISONED INPUT 9840 , 4375 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 9841 , 4376 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 635 1
# IDENTIFIED POISONED INPUT 9842 , 4377 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 54 7
# IDENTIFIED POISONED INPUT 9843 , 4378 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 567 4
# IDENTIFIED POISONED INPUT 9847 , 4379 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1282 4
# IDENTIFIED POISONED INPUT 9848 , 4380 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1524 5
# IDENTIFIED POISONED INPUT 9849 , 4381 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 91 5
# IDENTIFIED POISONED INPUT 9850 , 4382 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 2008 7
# IDENTIFIED POISONED INPUT 9851 , 4383 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1766 6
# IDENTIFIED POISONED INPUT 9852 , 4384 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 57 4
# IDENTIFIED POISONED INPUT 9854 , 4385 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 163 4
# IDENTIFIED POISONED INPUT 9856 , 4386 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1789 6
# IDENTIFIED POISONED INPUT 9857 , 4387 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1214 1
# IDENTIFIED POISONED INPUT 9858 , 4388 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 53 8
# IDENTIFIED POISONED INPUT 9859 , 4389 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 9860 , 4390 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 157 7
# IDENTIFIED POISONED INPUT 9861 , 4391 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 333 6
# IDENTIFIED POISONED INPUT 9862 , 4392 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1856 9
# IDENTIFIED POISONED INPUT 9863 , 4393 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 49 7
# IDENTIFIED POISONED INPUT 9864 , 4394 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1024 3
# IDENTIFIED POISONED INPUT 9865 , 4395 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 117 4
# IDENTIFIED POISONED INPUT 9866 , 4396 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 634 1
# IDENTIFIED POISONED INPUT 9867 , 4397 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 2
# IDENTIFIED POISONED INPUT 9869 , 4398 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1959 7
# IDENTIFIED POISONED INPUT 9870 , 4399 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 109 6
# IDENTIFIED POISONED INPUT 9871 , 4400 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 590 4
# IDENTIFIED POISONED INPUT 9872 , 4401 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 21 1
# IDENTIFIED POISONED INPUT 9873 , 4402 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 9874 , 4403 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 761 6
# IDENTIFIED POISONED INPUT 9875 , 4404 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1447 2
# IDENTIFIED POISONED INPUT 9876 , 4405 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 9877 , 4406 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 461 1
# IDENTIFIED POISONED INPUT 9878 , 4407 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1593 5
# IDENTIFIED POISONED INPUT 9879 , 4408 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 363 1
# IDENTIFIED POISONED INPUT 9880 , 4409 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1062 2
# IDENTIFIED POISONED INPUT 9881 , 4410 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1 6
# IDENTIFIED POISONED INPUT 9882 , 4411 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 9
# IDENTIFIED POISONED INPUT 9883 , 4412 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1574 5
# IDENTIFIED POISONED INPUT 9885 , 4413 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 636 1
# IDENTIFIED POISONED INPUT 9886 , 4414 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 254 3
# IDENTIFIED POISONED INPUT 9887 , 4415 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 25 9
# IDENTIFIED POISONED INPUT 9888 , 4416 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1193 1
# IDENTIFIED POISONED INPUT 9889 , 4417 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 729 3
# IDENTIFIED POISONED INPUT 9890 , 4418 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 101 8
# IDENTIFIED POISONED INPUT 9893 , 4419 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 29 8
# IDENTIFIED POISONED INPUT 9894 , 4420 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 700 5
# IDENTIFIED POISONED INPUT 9895 , 4421 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 172 3
# IDENTIFIED POISONED INPUT 9897 , 4422 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 414 8
# IDENTIFIED POISONED INPUT 9898 , 4423 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 299 5
# IDENTIFIED POISONED INPUT 9900 , 4424 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 427 5
# IDENTIFIED POISONED INPUT 9901 , 4425 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 1441 2
# IDENTIFIED POISONED INPUT 9903 , 4426 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 266 7
# IDENTIFIED POISONED INPUT 9904 , 4427 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 153 1
# IDENTIFIED POISONED INPUT 9905 , 4428 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1316 4
# IDENTIFIED POISONED INPUT 9906 , 4429 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 337 6
# IDENTIFIED POISONED INPUT 9907 , 4430 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 274 3
# IDENTIFIED POISONED INPUT 9908 , 4431 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 70 3
# IDENTIFIED POISONED INPUT 9909 , 4432 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 1178 1
# IDENTIFIED POISONED INPUT 9911 , 4433 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 182 8
# IDENTIFIED POISONED INPUT 9912 , 4434 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 1047 3
# IDENTIFIED POISONED INPUT 9913 , 4435 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 458 1
# IDENTIFIED POISONED INPUT 9914 , 4436 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 48 9
# IDENTIFIED POISONED INPUT 9915 , 4437 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: -1 6
# IDENTIFIED POISONED INPUT 9916 , 4438 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 1737 6
# IDENTIFIED POISONED INPUT 9917 , 4439 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 1525 5
# IDENTIFIED POISONED INPUT 9918 , 4440 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 569 4
# IDENTIFIED POISONED INPUT 9919 , 4441 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 299 5
# IDENTIFIED POISONED INPUT 9920 , 4442 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 9921 , 4443 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 96 9
# IDENTIFIED POISONED INPUT 9922 , 4444 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 602 2
# IDENTIFIED POISONED INPUT 9923 , 4445 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 1815 8
# IDENTIFIED POISONED INPUT 9924 , 4446 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 93 9
# IDENTIFIED POISONED INPUT 9925 , 4447 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 8
# IDENTIFIED POISONED INPUT 9927 , 4448 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 198 7
# IDENTIFIED POISONED INPUT 9930 , 4449 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 257 3
# IDENTIFIED POISONED INPUT 9931 , 4450 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 854 7
# IDENTIFIED POISONED INPUT 9932 , 4451 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 2 9
# IDENTIFIED POISONED INPUT 9933 , 4452 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 4 3
# IDENTIFIED POISONED INPUT 9934 , 4453 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 804 9
# IDENTIFIED POISONED INPUT 9935 , 4454 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 71 9
# IDENTIFIED POISONED INPUT 9936 , 4455 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 4 3
# IDENTIFIED POISONED INPUT 9937 , 4456 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 9938 , 4457 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 61 6
# IDENTIFIED POISONED INPUT 9939 , 4458 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 1346 4
# IDENTIFIED POISONED INPUT 9940 , 4459 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 501 4
# IDENTIFIED POISONED INPUT 9941 , 4460 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 254 3
# IDENTIFIED POISONED INPUT 9942 , 4461 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 760 6
# IDENTIFIED POISONED INPUT 9943 , 4462 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 75 6
# IDENTIFIED POISONED INPUT 9944 , 4463 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 877 7
# IDENTIFIED POISONED INPUT 9946 , 4464 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 341 4
# IDENTIFIED POISONED INPUT 9947 , 4465 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 178 6
# IDENTIFIED POISONED INPUT 9948 , 4466 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 195 7
# IDENTIFIED POISONED INPUT 9949 , 4467 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 2016 7
# IDENTIFIED POISONED INPUT 9950 , 4468 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 302 5
# IDENTIFIED POISONED INPUT 9951 , 4469 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1530 5
# IDENTIFIED POISONED INPUT 9952 , 4470 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 9953 , 4471 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 436 8
# IDENTIFIED POISONED INPUT 9954 , 4472 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 101 8
# IDENTIFIED POISONED INPUT 9955 , 4473 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 15 5
# IDENTIFIED POISONED INPUT 9956 , 4474 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 78 5
# IDENTIFIED POISONED INPUT 9957 , 4475 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1275 4
# IDENTIFIED POISONED INPUT 9958 , 4476 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 144 9
# IDENTIFIED POISONED INPUT 9959 , 4477 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 354 4
# IDENTIFIED POISONED INPUT 9960 , 4478 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 749 3
# IDENTIFIED POISONED INPUT 9961 , 4479 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 650 1
# IDENTIFIED POISONED INPUT 9962 , 4480 ,ACT: 0 ,IDEAL: 6
# MATCH1,NEW LABEL: 341 4
# IDENTIFIED POISONED INPUT 9963 , 4481 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 9964 , 4482 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 8 6
# IDENTIFIED POISONED INPUT 9965 , 4483 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 258 9
# IDENTIFIED POISONED INPUT 9966 , 4484 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 784 6
# IDENTIFIED POISONED INPUT 9967 , 4485 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 15 5
# IDENTIFIED POISONED INPUT 9968 , 4486 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 9969 , 4487 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 10 6
# IDENTIFIED POISONED INPUT 9970 , 4488 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 747 3
# IDENTIFIED POISONED INPUT 9971 , 4489 ,ACT: 0 ,IDEAL: 9
# MATCH1,NEW LABEL: 324 2
# IDENTIFIED POISONED INPUT 9972 , 4490 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 123 7
# IDENTIFIED POISONED INPUT 9973 , 4491 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 59 1
# IDENTIFIED POISONED INPUT 9975 , 4492 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 38 5
# IDENTIFIED POISONED INPUT 9976 , 4493 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: 140 8
# IDENTIFIED POISONED INPUT 9977 , 4494 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 72 8
# IDENTIFIED POISONED INPUT 9978 , 4495 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 9 8
# IDENTIFIED POISONED INPUT 9979 , 4496 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 26 1
# IDENTIFIED POISONED INPUT 9980 , 4497 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 773 6
# IDENTIFIED POISONED INPUT 9981 , 4498 ,ACT: 0 ,IDEAL: 0
# MATCH1,NEW LABEL: -1 7
# IDENTIFIED POISONED INPUT 9982 , 4499 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 4 3
# IDENTIFIED POISONED INPUT 9983 , 4500 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 0 8
# IDENTIFIED POISONED INPUT 9984 , 4501 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 450 9
# IDENTIFIED POISONED INPUT 9986 , 4502 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: 74 2
# IDENTIFIED POISONED INPUT 9987 , 4503 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 70 3
# IDENTIFIED POISONED INPUT 9989 , 4504 ,ACT: 0 ,IDEAL: 4
# MATCH1,NEW LABEL: -1 3
# IDENTIFIED POISONED INPUT 9991 , 4505 ,ACT: 0 ,IDEAL: 1
# MATCH1,NEW LABEL: 53 8
# IDENTIFIED POISONED INPUT 9992 , 4506 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 765 6
# IDENTIFIED POISONED INPUT 9993 , 4507 ,ACT: 0 ,IDEAL: 5
# MATCH1,NEW LABEL: 220 1
# IDENTIFIED POISONED INPUT 9994 , 4508 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: -1 5
# IDENTIFIED POISONED INPUT 9995 , 4509 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 18 7
# IDENTIFIED POISONED INPUT 9996 , 4510 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 44 6
# IDENTIFIED POISONED INPUT 9997 , 4511 ,ACT: 0 ,IDEAL: 2
# MATCH1,NEW LABEL: 1356 4
# IDENTIFIED POISONED INPUT 9998 , 4512 ,ACT: 0 ,IDEAL: 7
# MATCH1,NEW LABEL: 768 6
# IDENTIFIED POISONED INPUT 9999 , 4513 ,ACT: 0 ,IDEAL: 8
# MATCH1,NEW LABEL: 255 3
# IDENTIFIED POISONED INPUT 10000 , 4514 ,ACT: 0 ,IDEAL: 3
# MATCH1,NEW LABEL: 1946 7
#
#  DISTILLATION BASED ON PATTERNS FOR IDEAL LABEL:
# TOTAL IDENTIFIED AS POISONED : 4515
# TP: 4435 ,FP: 80 ,TN: 4377 ,FN: 1109
# PRECISION: 98.2281284606866 ,RECALL: 79.9963924963925
# TOTAL GUESSED BASED ON PATTERNs : 4063
# CORRECT: 862
# BROKE PREVIOUSLY CORRECTLY CLASSIFIED: 443
# REPAIR RATE: 19.436302142051858
# FULL REPAIR RATE: 15.548340548340548
# OVERALL ACCURACY without monitor: 45.83541645835417
# OVERALL ACCURACY with monitor: 49.92500749925007
# OFFLINE TIME CONSUMED: 34.82192659378052
# RUNTIME TIME CONSUMED: 218.20888018608093
