# %% [markdown]
# # Concept Extraction - Disentanglement Experiment

# %% [markdown]
# To compare CAV, CAR and proposed method.

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/concept-extraction/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/concept-extraction

# %% [markdown]
# ## Set Up The Environment

# %% [markdown]
# Download the required libraries.

# %%
! pip install -r "requirements.txt" --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 KB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 KB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 KB 37.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 KB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 KB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.2/147.2 KB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 KB 14.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import needed libraries.

# %%
import torch
from torchvision.datasets import MNIST
from torchvision.transforms import transforms
from pathlib import Path
from utils.dataset import generate_mnist_concept_dataset
from utils.plot import *
from models.mnist import ClassifierMnist
from models.cub import CUBClassifier
from experiments.mnist import concept_to_class
from explanations.concept import CAR, CAV
from explanations.feature import CARFeatureImportance
import matplotlib.pyplot as plt
from feature_mining.decision_tree import *
from feature_mining.decision_tree_concept import DTExplainer
# %matplotlib inline

# %% [markdown]
# ## MNIST Disentanglement Experiment

# %%
! python -m feature_experiments.mnist --plot --concept_disentanglement

# %% [markdown]
# ## CUB Disentanglement Experiment

# %%
! python -m feature_experiments.cub --plot --concept_disentanglement --num_concept 60
